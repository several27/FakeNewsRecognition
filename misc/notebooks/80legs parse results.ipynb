# %%
import multiprocessing

from tqdm import tqdm
import newspaper
import requests
import ujson

# %%
def download_all_results(api_token, crawl_name, out_path):
    with open(out_path, 'w') as _out:
        response = requests.get('https://' + api_token + ':@api.80legs.com/v2/results/' + crawl_name)
        result_files = response.json()
        for result_file in tqdm(result_files): 
            file_response = requests.get(result_file, stream=True)
            file_content = bytearray()
            for chunk in file_response.iter_content(chunk_size=1024):
                file_content.extend(chunk)

            try:
                results = ujson.loads(file_content.decode('utf-8'))
                for result in results: 
                    _out.write(ujson.dumps(result) + '\n')
            except Exception:
                print('Failed :(', crawl_name)

# %%
download_all_results('zkznwmuog07v6zjnef1igo32h80jtwo2', 'FakeNews_1', 'data/11_80legs/FakeNews_1_result.json')
# Out:
# 100%|██████████| 146/146 [23:49<00:00,  9.79s/it]

# %%
def process_result(result):
    result = ujson.loads(result)

    if 'url' not in result or 'result' not in result:
        return

    url = result['url']
    html = result['result']

    if url is None or html is None or len(html) <= 1:
        return

    article = newspaper.Article(url)
    article.set_html(html)
    article.parse()

    return ujson.dumps({
        'title': article.title,
        'body': article.text,
        'meta': {
            'original_id': url,
            'url': url,
            'published_at': article.publish_date,
            'raw': {
                'images': article.images,
                'favicon': article.meta_favicon,
                'tags': article.tags,
                'authors': article.authors,
                'top_image': article.top_image,
                'html': html
            }
        }
    }) + '\n'

# %%
with open('data/11_80legs/FakeNews_1_results_parsed.json', 'w') as _out: 
    with open('data/11_80legs/FakeNews_1_result.json', 'r') as _in: 
        bar = tqdm()
        pool = multiprocessing.Pool(processes=multiprocessing.cpu_count())
        for result in pool.imap(process_result, _in, 10):
            if result is None: 
                continue

            _out.write(result)
            bar.update()
# Out:
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.00s/it]
# 41it [00:06,  2.82s/it]
# 51it [00:06,  2.00s/it]
# 71it [00:07,  1.40s/it]
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.5/dist-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/usr/lib/python3.5/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#
# 12471it [11:48, 18.67it/s]WARNING:newspaper.parsers:fromstring() returned an invalid string: <!–...
# 13981it [12:55, 22.94it/s]WARNING:newspaper.parsers:fromstring() returned an invalid string: <!–...
# 22211it [24:38,  9.52it/s]/usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5818 bytes but only got 50. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5818 bytes but only got 1074. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5818 bytes but only got 2098. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5818 bytes but only got 3122. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5818 bytes but only got 4146. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5818 bytes but only got 5170. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# 30311it [36:50, 19.21it/s]WARNING:newspaper.parsers:fromstring() returned an invalid string:  ftypisomisom...
# 31011it [37:33, 14.39it/s]WARNING:newspaper.parsers:fromstring() returned an invalid string: ftypmp42mp42...
# 32211it [38:46,  9.49it/s]WARNING:newspaper.parsers:fromstring() returned an invalid string:  ftypisomisom...
# 35111it [42:38, 12.52it/s]WARNING:newspaper.parsers:fromstring() returned an invalid string:  ftypisomisom...
# 37881it [47:37,  2.49it/s]WARNING:newspaper.parsers:fromstring() returned an invalid string:  ftypisomisom...
# 50701it [1:02:50, 15.98it/s]WARNING:newspaper.parsers:fromstring() returned an invalid string: ftypmp42mp42...
# 54531it [1:05:38, 24.44it/s]WARNING:newspaper.parsers:fromstring() returned an invalid string: ftypmp42isom...
# WARNING:newspaper.parsers:fromstring() returned an invalid string: ftypmp42mp42...
# WARNING:newspaper.parsers:fromstring() returned an invalid string: ftypmp42mp42...
# WARNING:newspaper.parsers:fromstring() returned an invalid string: ftypmp42mp42...
# 59221it [1:10:10, 38.01it/s]WARNING:newspaper.parsers:fromstring() returned an invalid string:  ftypisomisom...
# 61821it [1:12:08, 25.92it/s]WARNING:newspaper.parsers:fromstring() returned an invalid string: <!–...
# WARNING:newspaper.parsers:fromstring() returned an invalid string: <!–...
# 61911it [1:12:11, 25.08it/s]WARNING:newspaper.parsers:fromstring() returned an invalid string: <!–...
# 62121it [1:12:20, 21.89it/s]WARNING:newspaper.parsers:fromstring() returned an invalid string: <!–...
# 90061it [1:36:20,  9.73it/s] /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 210. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 16 bytes but only got 0. Skipping tag 37510
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 41988
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 1234. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 2258. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 3282. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 4306. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 5330. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 6354. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 7378. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 8402. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 9426. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 10450. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 11474. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 12498. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 13522. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 14546. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 15570. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 16594. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 17618. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 18642. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 19666. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 20690. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 21714. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 22738. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 23762. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 24786. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 25810. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 26834. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 27858. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 28882. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 29906. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 30930. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32768 bytes but only got 31954. Skipping tag 37500
#   " Skipping tag %s" % (size, len(data), tag))
# 96781it [1:42:16, 25.21it/s]
