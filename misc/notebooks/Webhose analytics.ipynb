# %%
import os

import ujson
from tqdm import tqdm
from peewee import SqliteDatabase, fn
from playhouse.shortcuts import model_to_dict

from database import Page

# %%
path_data = '/Volumes/ExternalSSD/FakeNewsRecognition/'

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Extract-the-reliable-sources" data-toc-modified-id="Extract-the-reliable-sources-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Extract the reliable sources</a></span></li><li><span><a href="#Insert-webhose-to-standard-Page-DB-format" data-toc-modified-id="Insert-webhose-to-standard-Page-DB-format-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Insert webhose to standard Page DB format</a></span></li></ul></div>

# %%
path = '/Volumes/ExternalSSD/FakeNewsRecognition/624_webhose-2016-11_20170904081158/'

# %%
files = os.listdir(path)

# %%
domain_language_counter = {}

with tqdm() as progress:
    for file in files:
        with open(path + file, 'r') as in_file:
            for line in in_file:
                article = ujson.loads(line)
                domain = article['thread']['site_full']
                language = article['language']
                key = domain, language
                domain_language_counter.setdefault(key, 0)
                domain_language_counter[key] += 1
            
        progress.update()
# Out:
# 499610it [06:18, 1320.41it/s]

# %%
domain_language_counter_sorted = list(domain_language_counter.items())
sorted(domain_language_counter_sorted, key=lambda x: x[1], reverse=True)
# Out:
# [(('archive.org', 'english'), 50470),
#  (('www.reuters.com', 'english'), 33991),
#  (('answers.yahoo.com', 'english'), 24751),
#  (('www.yahoo.com', 'english'), 22454),
#  (('www.sfgate.com', 'english'), 22281),
#  (('www.chron.com', 'english'), 18532),
#  (('news.yahoo.com', 'english'), 16755),
#  (('uk.finance.yahoo.com', 'english'), 12715),
#  (('indianexpress.com', 'english'), 11672),
#  (('www.huffingtonpost.com', 'english'), 10939),
#  (('abcnews.go.com', 'english'), 8657),
#  (('www.msn.com', 'english'), 7629),
#  (('www.businessinsider.com', 'english'), 6681),
#  (('uk.reuters.com', 'english'), 6574),
#  (('www.theguardian.com', 'english'), 6370),
#  (('ca.reuters.com', 'english'), 5771),
#  (('www.wsj.com', 'english'), 5550),
#  (('af.reuters.com', 'english'), 5416),
#  (('www.nhl.com', 'english'), 5378),
#  (('www.legacy.com', 'english'), 5301),
#  (('tv.yahoo.com', 'english'), 5299),
#  (('www.latimes.com', 'english'), 5167),
#  (('www.washingtonpost.com', 'english'), 5074),
#  (('sports.yahoo.com', 'english'), 5057),
#  (('www.forbes.com', 'english'), 4933),
#  (('www.nytimes.com', 'english'), 4557),
#  (('www.nydailynews.com', 'english'), 4175),
#  (('www.bloomberg.com', 'english'), 4159),
#  (('in.reuters.com', 'english'), 4083),
#  (('www.usatoday.com', 'english'), 4075),
#  (('www.ndtv.com', 'english'), 3966),
#  (('music.yahoo.com', 'english'), 3787),
#  (('www.cnbc.com', 'english'), 3589),
#  (('ca.news.yahoo.com', 'english'), 3349),
#  (('www.cbsnews.com', 'english'), 3255),
#  (('www.marketwatch.com', 'english'), 3177),
#  (('www.reddit.com', 'english'), 3089),
#  (('m.mlb.com', 'english'), 3061),
#  (('nypost.com', 'english'), 3047),
#  (('www.npr.org', 'english'), 2742),
#  (('bleacherreport.com', 'english'), 2690),
#  (('zeenews.india.com', 'english'), 2672),
#  (('finance.yahoo.com', 'english'), 2451),
#  (('feeds.reuters.com', 'english'), 2306),
#  (('www.cbssports.com', 'english'), 2298),
#  (('edition.cnn.com', 'english'), 2285),
#  (('people.com', 'english'), 2223),
#  (('www.cnet.com', 'english'), 2182),
#  (('nz.sports.yahoo.com', 'english'), 2063),
#  (('news.abs-cbn.com', 'english'), 1943),
#  (('www.nba.com', 'english'), 1896),
#  (('www.slideshare.net', 'english'), 1870),
#  (('www.rediff.com', 'english'), 1845),
#  (('online.wsj.com', 'english'), 1810),
#  (('de.finance.yahoo.com', 'english'), 1746),
#  (('www.investing.com', 'english'), 1731),
#  (('www.cnn.com', 'english'), 1728),
#  (('www.eonline.com', 'english'), 1718),
#  (('indiatoday.intoday.in', 'english'), 1664),
#  (('www.ew.com', 'english'), 1656),
#  (('newsinfo.inquirer.net', 'english'), 1614),
#  (('www.nbcnews.com', 'english'), 1586),
#  (('www.politico.com', 'english'), 1581),
#  (('profit.ndtv.com', 'english'), 1486),
#  (('wiki.mozilla.org', 'english'), 1474),
#  (('disneyworld.disney.go.com', 'english'), 1440),
#  (('uk.news.yahoo.com', 'english'), 1425),
#  (('www.goal.com', 'english'), 1411),
#  (('www.popsugar.com', 'english'), 1381),
#  (('video.foxnews.com', 'english'), 1285),
#  (('ftw.usatoday.com', 'english'), 1219),
#  (('scifi.stackexchange.com', 'english'), 1184),
#  (('patch.com', 'english'), 1158),
#  (('london.backpage.com', 'english'), 1089),
#  (('au.finance.yahoo.com', 'english'), 1081),
#  (('memory-alpha.wikia.com', 'english'), 1048),
#  (('www.ign.com', 'english'), 1025),
#  (('latino.foxnews.com', 'english'), 1010),
#  (('nz.news.yahoo.com', 'english'), 967),
#  (('www.engadget.com', 'english'), 965),
#  (('www.vice.com', 'english'), 933),
#  (('www.wikihow.com', 'english'), 914),
#  (('me.ign.com', 'english'), 901),
#  (('cebudailynews.inquirer.net', 'english'), 888),
#  (('feeds.eonline.com', 'english'), 867),
#  (('gadgets.ndtv.com', 'english'), 849),
#  (('money.cnn.com', 'english'), 843),
#  (('www.thesportbible.com', 'english'), 832),
#  (('www.breitbart.com', 'english'), 809),
#  (('washpost.bloomberg.com', 'english'), 809),
#  (('www.gmanetwork.com', 'english'), 775),
#  (('au.be.yahoo.com', 'english'), 767),
#  (('www.realclearpolitics.com', 'english'), 739),
#  (('www.rt.com', 'english'), 712),
#  (('onlinelibrary.wiley.com', 'english'), 702),
#  (('motherboard.vice.com', 'english'), 657),
#  (('au.news.yahoo.com', 'english'), 643),
#  (('www.nfl.com', 'english'), 628),
#  (('www.buzzfeed.com', 'english'), 620),
#  (('www.tribunnews.com', 'english'), 617),
#  (('www.theatlantic.com', 'english'), 612),
#  (('www.foxnews.com', 'english'), 611),
#  (('www.rollingstone.com', 'english'), 587),
#  (('www.wittyfeed.com', 'english'), 556),
#  (('www.ncaa.com', 'english'), 553),
#  (('timesofindia.indiatimes.com', 'english'), 553),
#  (('www.pcmag.com', 'english'), 551),
#  (('www.tmz.com', 'english'), 547),
#  (('movies.ndtv.com', 'english'), 516),
#  (('www.gamespot.com', 'english'), 510),
#  (('www.vox.com', 'english'), 506),
#  (('lifestyle.inquirer.net', 'english'), 501),
#  (('medium.com', 'english'), 488),
#  (('www.y8.com', 'english'), 487),
#  (('business.inquirer.net', 'english'), 432),
#  (('nation.foxnews.com', 'english'), 429),
#  (('sports.ndtv.com', 'english'), 423),
#  (('communities.usaa.com', 'english'), 420),
#  (('sg.style.yahoo.com', 'english'), 385),
#  (('video.cnbc.com', 'english'), 380),
#  (('www.webmd.com', 'english'), 373),
#  (('news.sky.com', 'english'), 371),
#  (('entertainment.inquirer.net', 'english'), 368),
#  (('www.westernjournalism.com', 'english'), 366),
#  (('www.dailymail.co.uk', 'english'), 361),
#  (('www.theverge.com', 'english'), 358),
#  (('chemistry.about.com', 'english'), 358),
#  (('www.slate.com', 'english'), 354),
#  (('food.ndtv.com', 'english'), 353),
#  (('time.com', 'english'), 343),
#  (('themeforest.net', 'english'), 321),
#  (('au.sports.yahoo.com', 'english'), 319),
#  (('www.kickstarter.com', 'english'), 313),
#  (('opinion.inquirer.net', 'english'), 307),
#  (('www.wired.com', 'english'), 307),
#  (('southernfood.about.com', 'english'), 304),
#  (('weirdnews.about.com', 'english'), 293),
#  (('www.espncricinfo.com', 'english'), 285),
#  (('daily.bhaskar.com', 'english'), 285),
#  (('familycrafts.about.com', 'english'), 278),
#  (('contests.about.com', 'english'), 265),
#  (('hotels.about.com', 'english'), 259),
#  (('bbq.about.com', 'english'), 254),
#  (('news.vice.com', 'english'), 253),
#  (('itunes.apple.com', 'english'), 253),
#  (('pop.inquirer.net', 'english'), 252),
#  (('militaryhistory.about.com', 'english'), 251),
#  (('auto.ndtv.com', 'english'), 250),
#  (('honeymoons.about.com', 'english'), 250),
#  (('space.about.com', 'english'), 249),
#  (('atheism.about.com', 'english'), 249),
#  (('sg.news.yahoo.com', 'english'), 245),
#  (('kosherfood.about.com', 'english'), 243),
#  (('vegetarian.about.com', 'english'), 243),
#  (('usa.chinadaily.com.cn', 'english'), 243),
#  (('marriage.about.com', 'english'), 238),
#  (('cocktails.about.com', 'english'), 236),
#  (('www.bbc.co.uk', 'english'), 234),
#  (('littlerock.about.com', 'english'), 233),
#  (('www.houzz.com', 'english'), 233),
#  (('usgovinfo.about.com', 'english'), 233),
#  (('buddhism.about.com', 'english'), 229),
#  (('healing.about.com', 'english'), 229),
#  (('movies.about.com', 'english'), 228),
#  (('seattle.about.com', 'english'), 228),
#  (('uspolitics.about.com', 'english'), 227),
#  (('www.telegraph.co.uk', 'english'), 225),
#  (('laundry.about.com', 'english'), 225),
#  (('bestsellers.about.com', 'english'), 225),
#  (('toronto.about.com', 'english'), 225),
#  (('glutenfreecooking.about.com', 'english'), 224),
#  (('toys.about.com', 'english'), 224),
#  (('www.investopedia.com', 'english'), 223),
#  (('za.ign.com', 'english'), 222),
#  (('horses.about.com', 'english'), 222),
#  (('skincare.about.com', 'english'), 221),
#  (('phoenix.about.com', 'english'), 221),
#  (('in.news.yahoo.com', 'english'), 221),
#  (('sanfrancisco.about.com', 'english'), 221),
#  (('inventors.about.com', 'english'), 219),
#  (('womenshistory.about.com', 'english'), 219),
#  (('boston.about.com', 'english'), 216),
#  (('makeup.about.com', 'english'), 213),
#  (('painting.about.com', 'english'), 213),
#  (('gosoutheast.about.com', 'english'), 208),
#  (('wordprocessing.about.com', 'english'), 208),
#  (('brooklyn.about.com', 'english'), 206),
#  (('hairremoval.about.com', 'english'), 205),
#  (('vancouver.about.com', 'english'), 203),
#  (('chinesefood.about.com', 'english'), 202),
#  (('manhattan.about.com', 'english'), 200),
#  (('wowwiki.wikia.com', 'english'), 199),
#  (('www.redtube.com', 'english'), 196),
#  (('artsandcrafts.about.com', 'english'), 195),
#  (('businessmajors.about.com', 'english'), 194),
#  (('drawsketch.about.com', 'english'), 193),
#  (('sg.finance.yahoo.com', 'english'), 192),
#  (('entertainment.abs-cbn.com', 'english'), 191),
#  (('climbing.about.com', 'english'), 184),
#  (('sports.abs-cbn.com', 'english'), 177),
#  (('radio.foxnews.com', 'english'), 177),
#  (('www.howtogeek.com', 'english'), 177),
#  (('genealogy.about.com', 'english'), 177),
#  (('webclipart.about.com', 'english'), 175),
#  (('gocentralamerica.about.com', 'english'), 170),
#  (('www.tomshardware.com', 'english'), 169),
#  (('technology.inquirer.net', 'english'), 167),
#  (('www.wiley.com', 'english'), 166),
#  (('cheerleading.about.com', 'english'), 166),
#  (('quilting.about.com', 'english'), 165),
#  (('uk.style.yahoo.com', 'english'), 164),
#  (('boardgames.about.com', 'english'), 164),
#  (('crime.about.com', 'english'), 164),
#  (('archaeology.about.com', 'english'), 161),
#  (('dogs.about.com', 'english'), 161),
#  (('spanish.about.com', 'english'), 158),
#  (('homecooking.about.com', 'english'), 157),
#  (('spreadsheets.about.com', 'english'), 157),
#  (('english.manoramaonline.com', 'english'), 156),
#  (('casinogambling.about.com', 'english'), 156),
#  (('economics.about.com', 'english'), 156),
#  (('canadaonline.about.com', 'english'), 154),
#  (('giphy.com', 'english'), 152),
#  (('globalnation.inquirer.net', 'english'), 151),
#  (('goflorida.about.com', 'english'), 151),
#  (('techcrunch.com', 'english'), 150),
#  (('k6educators.about.com', 'english'), 146),
#  (('golf.about.com', 'english'), 145),
#  (('gogreece.about.com', 'english'), 143),
#  (('uk.movies.yahoo.com', 'english'), 139),
#  (('montreal.about.com', 'english'), 136),
#  (('arthistory.about.com', 'english'), 136),
#  (('desktoppub.about.com', 'english'), 136),
#  (('freshaquarium.about.com', 'english'), 133),
#  (('thump.vice.com', 'english'), 132),
#  (('french.stackexchange.com', 'english'), 130),
#  (('cats.about.com', 'english'), 128),
#  (('gocalifornia.about.com', 'english'), 128),
#  (('manchester.backpage.com', 'english'), 128),
#  (('christianity.about.com', 'english'), 127),
#  (('math.stackexchange.com', 'english'), 126),
#  (('goafrica.about.com', 'english'), 124),
#  (('fashion.about.com', 'english'), 124),
#  (('usliberals.about.com', 'english'), 121),
#  (('thecairopost.youm7.com', 'english'), 120),
#  (('www.aol.com', 'english'), 118),
#  (('sound.stackexchange.com', 'english'), 117),
#  (('dc.about.com', 'english'), 117),
#  (('americanhistory.about.com', 'english'), 116),
#  (('me.pcmag.com', 'english'), 113),
#  (('familyinternet.about.com', 'english'), 111),
#  (('gogermany.about.com', 'english'), 109),
#  (('www.bbc.com', 'english'), 108),
#  (('civilliberty.about.com', 'english'), 107),
#  (('bandera.inquirer.net', 'english'), 105),
#  (('graphicssoft.about.com', 'english'), 105),
#  (('au.tv.yahoo.com', 'english'), 104),
#  (('rssfeeds.usatoday.com', 'english'), 103),
#  (('gocanada.about.com', 'english'), 102),
#  (('architecture.about.com', 'english'), 101),
#  (('vimeo.com', 'english'), 101),
#  (('africanhistory.about.com', 'english'), 100),
#  (('nl.ign.com', 'english'), 98),
#  (('disasterlit.nlm.nih.gov', 'english'), 98),
#  (('top40.about.com', 'english'), 95),
#  (('biology.about.com', 'english'), 95),
#  (('biz.yahoo.com', 'english'), 94),
#  (('www.cracked.com', 'english'), 92),
#  (('gardening.about.com', 'english'), 92),
#  (('munchies.vice.com', 'english'), 91),
#  (('it.notizie.yahoo.com', 'english'), 90),
#  (('goeasteurope.about.com', 'english'), 89),
#  (('codegolf.stackexchange.com', 'english'), 89),
#  (('insider.foxnews.com', 'english'), 89),
#  (('security.stackexchange.com', 'english'), 88),
#  (('gohawaii.about.com', 'english'), 86),
#  (('gocaribbean.about.com', 'english'), 86),
#  (('tw.news.yahoo.com', 'english'), 84),
#  (('www.abplive.in', 'english'), 84),
#  (('airtravel.about.com', 'english'), 83),
#  (('tex.stackexchange.com', 'english'), 83),
#  (('fivethirtyeight.com', 'english'), 83),
#  (('gma.yahoo.com', 'english'), 83),
#  (('greekfood.about.com', 'english'), 82),
#  (('espn.go.com', 'english'), 82),
#  (('kansascity.about.com', 'english'), 82),
#  (('worldbuilding.stackexchange.com', 'english'), 82),
#  (('www.thekitchn.com', 'english'), 81),
#  (('news.mit.edu', 'english'), 80),
#  (('en.farsnews.com', 'english'), 80),
#  (('goeurope.about.com', 'english'), 76),
#  (('motioncars.inquirer.net', 'english'), 75),
#  (('in.finance.yahoo.com', 'english'), 75),
#  (('www.cricbuzz.com', 'english'), 74),
#  (('abc.go.com', 'english'), 74),
#  (('www.yenisafak.com', 'english'), 73),
#  (('womensissues.about.com', 'english'), 72),
#  (('college.usatoday.com', 'english'), 70),
#  (('br.ign.com', 'english'), 69),
#  (('christianmusic.about.com', 'english'), 69),
#  (('football.about.com', 'english'), 69),
#  (('cleveland.about.com', 'english'), 68),
#  (('fatherhood.about.com', 'english'), 67),
#  (('goamsterdam.about.com', 'english'), 67),
#  (('antiques.about.com', 'english'), 66),
#  (('gochina.about.com', 'english'), 65),
#  (('puzzling.stackexchange.com', 'english'), 65),
#  (('usconservatives.about.com', 'english'), 63),
#  (('uk.sports.yahoo.com', 'english'), 63),
#  (('news.xinhuanet.com', 'english'), 61),
#  (('travel.stackexchange.com', 'english'), 61),
#  (('www.change.org', 'english'), 61),
#  (('ru.ign.com', 'english'), 61),
#  (('uk.businessinsider.com', 'english'), 60),
#  (('appexchange.salesforce.com', 'english'), 60),
#  (('goaustralia.about.com', 'english'), 60),
#  (('in.style.yahoo.com', 'english'), 59),
#  (('chk.tbe.taleo.net', 'english'), 59),
#  (('www.india.com', 'english'), 59),
#  (('rpg.stackexchange.com', 'english'), 58),
#  (('autorepair.about.com', 'english'), 58),
#  (('belfast.backpage.com', 'english'), 58),
#  (('academia.stackexchange.com', 'english'), 57),
#  (('dk.ign.com', 'english'), 56),
#  (('cruises.about.com', 'english'), 55),
#  (('www3.nhk.or.jp', 'english'), 55),
#  (('gourmetfood.about.com', 'english'), 55),
#  (('budgettravel.about.com', 'english'), 55),
#  (('alerts.weather.gov', 'english'), 53),
#  (('www.imdb.com', 'english'), 53),
#  (('glasgow.backpage.com', 'english'), 52),
#  (('gochicago.about.com', 'english'), 52),
#  (('hk.sports.yahoo.com', 'english'), 52),
#  (('bangka.tribunnews.com', 'english'), 52),
#  (('www.eventbrite.com', 'english'), 51),
#  (('babyproducts.about.com', 'english'), 51),
#  (('www.asahi.com', 'english'), 51),
#  (('mystarbucksidea.force.com', 'english'), 51),
#  (('www.worldlifestyle.com', 'english'), 50),
#  (('english.stackexchange.com', 'english'), 50),
#  (('graphicdesign.about.com', 'english'), 50),
#  (('uk.investing.com', 'english'), 50),
#  (('camping.about.com', 'english'), 50),
#  (('linux.about.com', 'english'), 48),
#  (('birminghamuk.backpage.com', 'english'), 48),
#  (('pt.ign.com', 'english'), 48),
#  (('news.nike.com', 'english'), 48),
#  (('es.ign.com', 'english'), 47),
#  (('boards.ancestry.com', 'english'), 47),
#  (('fishing.about.com', 'english'), 47),
#  (('edinburgh.backpage.com', 'english'), 46),
#  (('insider.espn.go.com', 'english'), 46),
#  (('jambi.tribunnews.com', 'english'), 46),
#  (('preen.inquirer.net', 'english'), 46),
#  (('www.verizon.com', 'english'), 46),
#  (('www.babycenter.com', 'english'), 45),
#  (('unix.stackexchange.com', 'english'), 45),
#  (('anime.about.com', 'english'), 45),
#  (('electronics.stackexchange.com', 'english'), 45),
#  (('politicalhumor.about.com', 'english'), 44),
#  (('in.investing.com', 'english'), 43),
#  (('ca.investing.com', 'english'), 43),
#  (('nz.lifestyle.yahoo.com', 'english'), 43),
#  (('usmilitary.about.com', 'english'), 43),
#  (('atlanta.about.com', 'english'), 43),
#  (('rap.about.com', 'english'), 43),
#  (('mathematica.stackexchange.com', 'english'), 42),
#  (('ell.stackexchange.com', 'english'), 42),
#  (('it.reuters.com', 'english'), 42),
#  (('it.ign.com', 'english'), 41),
#  (('za.investing.com', 'english'), 41),
#  (('ca.style.yahoo.com', 'english'), 41),
#  (('beer.about.com', 'english'), 40),
#  (('feeds.mashable.com', 'english'), 39),
#  (('workplace.stackexchange.com', 'english'), 39),
#  (('www.faithtap.com', 'english'), 38),
#  (('de.ign.com', 'english'), 38),
#  (('environment.about.com', 'english'), 37),
#  (('lampung.tribunnews.com', 'english'), 36),
#  (('medan.tribunnews.com', 'english'), 36),
#  (('productivity.stackexchange.com', 'english'), 36),
#  (('fr.style.yahoo.com', 'english'), 35),
#  (('news.xbox.com', 'english'), 35),
#  (('usun.state.gov', 'english'), 35),
#  (('comicbooks.about.com', 'english'), 34),
#  (('french.xinhuanet.com', 'english'), 34),
#  (('city.udn.com', 'english'), 34),
#  (('businesstravel.about.com', 'english'), 33),
#  (('detroit.about.com', 'english'), 33),
#  (('boxing.about.com', 'english'), 33),
#  (('wxdata.weather.com', 'english'), 32),
#  (('mx.reuters.com', 'english'), 32),
#  (('content-service.bloomberg.com', 'english'), 31),
#  (('esports.inquirer.net', 'english'), 31),
#  (('i-d.vice.com', 'english'), 31),
#  (('movies.stackexchange.com', 'english'), 30),
#  (('www.dictionary.com', 'english'), 29),
#  (('uk.answers.yahoo.com', 'english'), 28),
#  (('miami.backpage.com', 'english'), 28),
#  (('essex.backpage.com', 'english'), 28),
#  (('comicvine.gamespot.com', 'english'), 28),
#  (('mashable.com', 'english'), 28),
#  (('beauty.about.com', 'english'), 27),
#  (('www.insidecdcr.ca.gov', 'english'), 27),
#  (('www.bhaskar.com', 'english'), 27),
#  (('conservativetribune.com', 'english'), 27),
#  (('aviation.stackexchange.com', 'english'), 27),
#  (('motto.time.com', 'english'), 27),
#  (('palembang.tribunnews.com', 'english'), 27),
#  (('stateimpact.npr.org', 'english'), 27),
#  (('fr.finance.yahoo.com', 'english'), 27),
#  (('issuu.com', 'english'), 27),
#  (('www.ed.gov', 'english'), 27),
#  (('cookpad.com', 'english'), 26),
#  (('www.niaid.nih.gov', 'english'), 26),
#  (('economictimes.indiatimes.com', 'english'), 26),
#  (('codereview.stackexchange.com', 'english'), 26),
#  (('everylifecounts.ndtv.com', 'english'), 26),
#  (('videocast.nih.gov', 'english'), 26),
#  (('www.meetup.com', 'english'), 25),
#  (('pr.nba.com', 'english'), 25),
#  (('kent.backpage.com', 'english'), 25),
#  (('www.instructables.com', 'english'), 25),
#  (('albuquerque.about.com', 'english'), 25),
#  (('gaming.stackexchange.com', 'english'), 25),
#  (('widerimage.reuters.com', 'english'), 24),
#  (('figureskating.about.com', 'english'), 24),
#  (('batam.tribunnews.com', 'english'), 24),
#  (('leeds.backpage.com', 'english'), 23),
#  (('liverpool.backpage.com', 'english'), 23),
#  (('adventuretravel.about.com', 'english'), 22),
#  (('austin.about.com', 'english'), 22),
#  (('hampshire.backpage.com', 'english'), 21),
#  (('asia.nikkei.com', 'english'), 21),
#  (('www.nlm.nih.gov', 'english'), 21),
#  (('tw.stock.yahoo.com', 'english'), 21),
#  (('newcastle.backpage.com', 'english'), 20),
#  (('www-03.ibm.com', 'english'), 20),
#  (('eastmidlands.backpage.com', 'english'), 19),
#  (('live.washingtonpost.com', 'english'), 19),
#  (('wales.backpage.com', 'english'), 19),
#  (('mechanics.stackexchange.com', 'english'), 19),
#  (('www.realtor.com', 'english'), 19),
#  (('www.urbandictionary.com', 'english'), 18),
#  (('aberdeen.backpage.com', 'english'), 18),
#  (('newsroom.bankofamerica.com', 'english'), 18),
#  (('jp.reuters.com', 'english'), 18),
#  (('gizmodo.com', 'english'), 18),
#  (('superuser.com', 'english'), 17),
#  (('www.mirror.co.uk', 'english'), 17),
#  (('kimriddlebarger.squarespace.com', 'english'), 17),
#  (('newyork.craigslist.org', 'english'), 17),
#  (('money.stackexchange.com', 'english'), 17),
#  (('sheffield.backpage.com', 'english'), 17),
#  (('news.marriott.com', 'english'), 16),
#  (('wartakota.tribunnews.com', 'english'), 16),
#  (('home.bt.com', 'english'), 16),
#  (('www.yelp.com', 'english'), 16),
#  (('rss.cnn.com', 'english'), 16),
#  (('politics.stackexchange.com', 'english'), 16),
#  (('bristol.backpage.com', 'english'), 15),
#  (('ca.movies.yahoo.com', 'english'), 15),
#  (('www.zillow.com', 'english'), 15),
#  (('denver.about.com', 'english'), 15),
#  (('jabar.tribunnews.com', 'english'), 15),
#  (('brighton.backpage.com', 'english'), 15),
#  (('softwareengineering.stackexchange.com', 'english'), 15),
#  (('meta.stackexchange.com', 'english'), 15),
#  (('100photos.time.com', 'english'), 14),
#  (('ca.finance.yahoo.com', 'english'), 14),
#  (('sitecore.stackexchange.com', 'english'), 14),
#  (('www.kooora.com', 'english'), 14),
#  (('tw.sports.yahoo.com', 'english'), 14),
#  (('cooking.nytimes.com', 'english'), 14),
#  (('sports.inquirer.net', 'english'), 14),
#  (('kotaku.com', 'english'), 14),
#  (('eastanglia.backpage.com', 'english'), 14),
#  (('www.xda-developers.com', 'english'), 14),
#  (('ux.stackexchange.com', 'english'), 13),
#  (('www.redbooks.ibm.com', 'english'), 13),
#  (('latam.ign.com', 'english'), 13),
#  (('markets.businessinsider.com', 'english'), 13),
#  (('air.mozilla.org', 'english'), 13),
#  (('video.ew.com', 'english'), 13),
#  (('de.style.yahoo.com', 'english'), 13),
#  (('photo.stackexchange.com', 'english'), 13),
#  (('gouk.about.com', 'english'), 13),
#  (('losangeles.craigslist.org', 'english'), 13),
#  (('hurricanes.nhl.com', 'english'), 13),
#  (('lifehacker.com', 'english'), 13),
#  (('misti.mit.edu', 'english'), 13),
#  (('fans.capitals.nhl.com', 'english'), 13),
#  (('boxingjunkie.usatoday.com', 'english'), 13),
#  (('it.finance.yahoo.com', 'english'), 12),
#  (('dallas.craigslist.org', 'english'), 12),
#  (('fans.wild.nhl.com', 'english'), 12),
#  (('oag.ca.gov', 'english'), 12),
#  (('jets.nhl.com', 'english'), 12),
#  (('www.gov.uk', 'english'), 12),
#  (('okc.about.com', 'english'), 12),
#  (('jp.investing.com', 'english'), 12),
#  (('capitals.nhl.com', 'english'), 12),
#  (('stlouis.about.com', 'english'), 11),
#  (('au.answers.yahoo.com', 'english'), 11),
#  (('japan.cnet.com', 'english'), 11),
#  (('avalanche.nhl.com', 'english'), 11),
#  (('www.morgan-hill.ca.gov', 'english'), 11),
#  (('au.investing.com', 'english'), 11),
#  (('store.steampowered.com', 'english'), 11),
#  (('www.wunderground.com', 'english'), 11),
#  (('news.delta.com', 'english'), 11),
#  (('chicago.about.com', 'english'), 11),
#  (('fr.news.yahoo.com', 'english'), 10),
#  (('physics.stackexchange.com', 'english'), 10),
#  (('cooking.stackexchange.com', 'english'), 10),
#  (('beautypageants.indiatimes.com', 'english'), 10),
#  (('www.thehindu.com', 'english'), 10),
#  (('support.apple.com', 'english'), 10),
#  (('themeparks.about.com', 'english'), 10),
#  (('vid.me', 'english'), 10),
#  (('www.biobiochile.cl', 'english'), 10),
#  (('www.oracle.com', 'english'), 10),
#  (('gis.stackexchange.com', 'english'), 10),
#  (('golosangeles.about.com', 'english'), 10),
#  (('www.cde.ca.gov', 'english'), 10),
#  (('it.celebrity.yahoo.com', 'english'), 10),
#  (('columbusoh.about.com', 'english'), 10),
#  (('push.abs-cbn.com', 'english'), 10),
#  (('live.reuters.com', 'english'), 9),
#  (('chemistry.stackexchange.com', 'english'), 9),
#  (('adulted.about.com', 'english'), 9),
#  (('hometheater.about.com', 'english'), 9),
#  (('cs.stackexchange.com', 'english'), 9),
#  (('devils.nhl.com', 'english'), 9),
#  (('govegas.about.com', 'english'), 9),
#  (('nz.travel.yahoo.com', 'english'), 9),
#  (('au.pfinance.yahoo.com', 'english'), 9),
#  (('www1.macys.com', 'english'), 9),
#  (('bicycles.stackexchange.com', 'english'), 9),
#  (('ducks.nhl.com', 'english'), 9),
#  (('blues.nhl.com', 'english'), 9),
#  (('www.apple.com', 'english'), 9),
#  (('dish.allrecipes.com', 'english'), 9),
#  (('swachhindia.ndtv.com', 'english'), 9),
#  (('stag2.wired.com', 'english'), 9),
#  (('shanghai.auto.qq.com', 'english'), 9),
#  (('rvtravel.about.com', 'english'), 9),
#  (('news.walmart.com', 'english'), 9),
#  (('blogs.windows.com', 'english'), 9),
#  (('japanese.stackexchange.com', 'english'), 9),
#  (('sharepoint.stackexchange.com', 'english'), 9),
#  (('dba.stackexchange.com', 'english'), 8),
#  (('faithtap.com', 'english'), 8),
#  (('developer.apple.com', 'english'), 8),
#  (('exame.abril.com.br', 'english'), 8),
#  (('sandiego.craigslist.org', 'english'), 8),
#  (('spas.about.com', 'english'), 8),
#  (('kidsmusic.about.com', 'english'), 8),
#  (('news.china.com.cn', 'english'), 8),
#  (('fans.flames.nhl.com', 'english'), 8),
#  (('feeds.foxnews.com', 'english'), 8),
#  (('gonewengland.about.com', 'english'), 8),
#  (('developer.ibm.com', 'english'), 8),
#  (('music.stackexchange.com', 'english'), 8),
#  (('cambridge.backpage.com', 'english'), 8),
#  (('www.nih.gov', 'english'), 8),
#  (('goindia.about.com', 'english'), 8),
#  (('devon.backpage.com', 'english'), 8),
#  (('mapleleafs.nhl.com', 'english'), 7),
#  (('in.answers.yahoo.com', 'english'), 7),
#  (('www.theladbible.com', 'english'), 7),
#  (('gomexico.about.com', 'english'), 7),
#  (('magento.stackexchange.com', 'english'), 7),
#  (('dicocitations.lemonde.fr', 'english'), 7),
#  (('mitsloanexperts.mit.edu', 'english'), 7),
#  (('golondon.about.com', 'english'), 7),
#  (('www.bhphotovideo.com', 'english'), 7),
#  (('myemail.constantcontact.com', 'english'), 7),
#  (('goireland.about.com', 'english'), 7),
#  (('pba.inquirer.net', 'english'), 7),
#  (('codecanyon.net', 'english'), 7),
#  (('traveltech.about.com', 'english'), 7),
#  (('boston.craigslist.org', 'english'), 7),
#  (('auto.qq.com', 'english'), 7),
#  (('taxprocenter.proconnect.intuit.com', 'english'), 7),
#  (('seattle.craigslist.org', 'english'), 7),
#  (('food.manoramaonline.com', 'english'), 7),
#  (('graphics.wsj.com', 'english'), 7),
#  (('crypto.stackexchange.com', 'english'), 7),
#  (('travelwithkids.about.com', 'english'), 7),
#  (('www-tracey.archive.org', 'english'), 7),
#  (('islanders.nhl.com', 'english'), 6),
#  (('overlandtravel.about.com', 'english'), 6),
#  (('guangzhou.auto.qq.com', 'english'), 6),
#  (('ryot.huffingtonpost.com', 'english'), 6),
#  (('miami.craigslist.org', 'english'), 6),
#  (('ehp.niehs.nih.gov', 'english'), 6),
#  (('diy.stackexchange.com', 'english'), 6),
#  (('tr.ign.com', 'english'), 6),
#  (('gonw.about.com', 'english'), 6),
#  (('gocolorado.about.com', 'english'), 6),
#  (('moohfashion.weebly.com', 'english'), 6),
#  (('tampa.craigslist.org', 'english'), 6),
#  (('uk.backpage.com', 'english'), 6),
#  (('www.icc-cricket.com', 'english'), 6),
#  (('ca.answers.yahoo.com', 'english'), 6),
#  (('louisville.about.com', 'english'), 6),
#  (('thump2.vice.com', 'english'), 6),
#  (('foodtravel.about.com', 'english'), 6),
#  (('ir.jcpenney.com', 'english'), 6),
#  (('usatravel.about.com', 'english'), 6),
#  (('manado.tribunnews.com', 'english'), 6),
#  (('brandequity.economictimes.indiatimes.com', 'english'), 6),
#  (('denver.craigslist.org', 'english'), 6),
#  (('espanol.answers.yahoo.com', 'english'), 6),
#  (('wuhan.auto.qq.com', 'english'), 6),
#  (('mumbaimirror.indiatimes.com', 'english'), 6),
#  (('vermont.craigslist.org', 'english'), 6),
#  (('hearsegurl.deviantart.com', 'english'), 6),
#  (('redwings.nhl.com', 'english'), 6),
#  (('www.marriott.com', 'english'), 6),
#  (('cellphones.about.com', 'english'), 6),
#  (('newsroom.cisco.com', 'english'), 6),
#  (('nz.entertainment.yahoo.com', 'english'), 6),
#  (('gaytravel.about.com', 'english'), 6),
#  (('www.calbar.ca.gov', 'english'), 6),
#  (('outdoors.stackexchange.com', 'english'), 6),
#  (('jp.techcrunch.com', 'english'), 5),
#  (('www.ncbi.nlm.nih.gov', 'english'), 5),
#  (('gofrance.about.com', 'english'), 5),
#  (('uk-sport-f1.yahoo.com', 'english'), 5),
#  (('chicago.craigslist.org', 'english'), 5),
#  (('esperanto.stackexchange.com', 'english'), 5),
#  (('www.adp.com', 'english'), 5),
#  (('denverfrank.weebly.com', 'english'), 5),
#  (('houston.about.com', 'english'), 5),
#  (('gamedev.stackexchange.com', 'english'), 5),
#  (('nccih.nih.gov', 'english'), 5),
#  (('magazine.foxnews.com', 'english'), 5),
#  (('www.nichd.nih.gov', 'english'), 5),
#  (('jogja.tribunnews.com', 'english'), 5),
#  (('bath.backpage.com', 'english'), 5),
#  (('shoals.backpage.com', 'english'), 5),
#  (('jp.wsj.com', 'english'), 5),
#  (('grants.nih.gov', 'english'), 5),
#  (('ncbiinsights.ncbi.nlm.nih.gov', 'english'), 5),
#  (('video.latino.foxnews.com', 'english'), 5),
#  (('austin.craigslist.org', 'english'), 5),
#  (('graphicdesign.stackexchange.com', 'english'), 5),
#  (('filehippo.com', 'english'), 5),
#  (('www.calpers.ca.gov', 'english'), 5),
#  (('uae.souq.com', 'english'), 5),
#  (('milesandpoints.about.com', 'english'), 5),
#  (('rangers.nhl.com', 'english'), 5),
#  (('nces.ed.gov', 'english'), 5),
#  (('goparis.about.com', 'english'), 5),
#  (('stats.stackexchange.com', 'english'), 5),
#  (('www8.hp.com', 'english'), 5),
#  (('slice.mit.edu', 'english'), 5),
#  (('www.gearbest.com', 'english'), 5),
#  (('orangecounty.craigslist.org', 'english'), 5),
#  (('tech.economictimes.indiatimes.com', 'english'), 5),
#  (('us.blastingnews.com', 'english'), 5),
#  (('shenyang.auto.qq.com', 'english'), 5),
#  (('es-us.noticias.yahoo.com', 'english'), 5),
#  (('gotexas.about.com', 'english'), 5),
#  (('oxford.backpage.com', 'english'), 5),
#  (('addons.mozilla.org', 'english'), 5),
#  (('sites.ndtv.com', 'english'), 5),
#  (('on.nfl.com', 'english'), 4),
#  (('www.youm7.com', 'english'), 4),
#  (('elections.huffingtonpost.com', 'english'), 4),
#  (('charlotte.about.com', 'english'), 4),
#  (('space.stackexchange.com', 'english'), 4),
#  (('www.snapdeal.com', 'english'), 4),
#  (('ghr.nlm.nih.gov', 'english'), 4),
#  (('graphics.latimes.com', 'english'), 4),
#  (('m.liputan6.com', 'english'), 4),
#  (('luxurytravel.about.com', 'english'), 4),
#  (('de.investing.com', 'english'), 4),
#  (('biology.stackexchange.com', 'english'), 4),
#  (('fanindex.usatoday.com', 'english'), 4),
#  (('one.npr.org', 'english'), 4),
#  (('tuscaloosa.backpage.com', 'english'), 4),
#  (('inthenews.mayoclinic.org', 'english'), 4),
#  (('flyfishing.about.com', 'english'), 4),
#  (('de.sports.yahoo.com', 'english'), 4),
#  (('data.cnbc.com', 'english'), 4),
#  (('astronomy.stackexchange.com', 'english'), 4),
#  (('fortmyers.craigslist.org', 'english'), 4),
#  (('parenting.stackexchange.com', 'english'), 4),
#  (('www.ticketmaster.com', 'english'), 4),
#  (('www.niehs.nih.gov', 'english'), 4),
#  (('telecom.economictimes.indiatimes.com', 'english'), 4),
#  (('patriotswire.usatoday.com', 'english'), 4),
#  (('pantherswire.usatoday.com', 'english'), 4),
#  (('heartbeat.skype.com', 'english'), 4),
#  (('weirdandamazingtravel.about.com', 'english'), 4),
#  (('www.alibaba.com', 'english'), 4),
#  (('travel.manoramaonline.com', 'english'), 4),
#  (('about.att.com', 'english'), 4),
#  (('se.ign.com', 'english'), 4),
#  (('weather.com', 'english'), 4),
#  (('aajtak.intoday.in', 'english'), 4),
#  (('sportspolls.usatoday.com', 'english'), 4),
#  (('www.foodnetwork.com', 'english'), 4),
#  (('seniortravel.about.com', 'english'), 4),
#  (('steelerswire.usatoday.com', 'english'), 4),
#  (('apple.stackexchange.com', 'english'), 4),
#  (('japanese.engadget.com', 'english'), 4),
#  (('compnetworking.about.com', 'english'), 4),
#  (('goasia.about.com', 'english'), 4),
#  (('lightning.nhl.com', 'english'), 4),
#  (('editorsnote.cocolog-nifty.com', 'english'), 4),
#  (('travelinsurance.about.com', 'english'), 4),
#  (('slickdeals.net', 'english'), 4),
#  (('theeagleswire.usatoday.com', 'english'), 4),
#  (('ocala.craigslist.org', 'english'), 4),
#  (('sports.vice.com', 'english'), 3),
#  (('www.accuweather.com', 'english'), 3),
#  (('dallas.about.com', 'english'), 3),
#  (('lat.wsj.com', 'english'), 3),
#  (('skeptics.stackexchange.com', 'english'), 3),
#  (('emacs.stackexchange.com', 'english'), 3),
#  (('esports.yahoo.com', 'english'), 3),
#  (('goodtimes.ndtv.com', 'english'), 3),
#  (('goneworleans.about.com', 'english'), 3),
#  (('bearswire.usatoday.com', 'english'), 3),
#  (('skillet.lifehacker.com', 'english'), 3),
#  (('libraries.mit.edu', 'english'), 3),
#  (('billswire.usatoday.com', 'english'), 3),
#  (('www.ultimate-guitar.com', 'english'), 3),
#  (('www.audible.com', 'english'), 3),
#  (('admin.salesforce.com', 'english'), 3),
#  (('nz.finance.yahoo.com', 'english'), 3),
#  (('www.speedtest.net', 'english'), 3),
#  (('web.mit.edu', 'english'), 3),
#  (('cowboyswire.usatoday.com', 'english'), 3),
#  (('sfbay.craigslist.org', 'english'), 3),
#  (('latin.stackexchange.com', 'english'), 3),
#  (('gospain.about.com', 'english'), 3),
#  (('radio.cbssports.com', 'english'), 3),
#  (('watch.nba.com', 'english'), 3),
#  (('cnews.chinadaily.com.cn', 'english'), 3),
#  (('learn.infusionsoft.com', 'english'), 3),
#  (('smallspaces.about.com', 'english'), 3),
#  (('www.lemonde.fr', 'english'), 3),
#  (('gonyc.about.com', 'english'), 3),
#  (('www.chinadaily.com.cn', 'english'), 3),
#  (('goseasia.about.com', 'english'), 3),
#  (('es-us.vida-estilo.yahoo.com', 'english'), 3),
#  (('digitalservices.npr.org', 'english'), 3),
#  (('history.stackexchange.com', 'english'), 3),
#  (('au.prime7.yahoo.com', 'english'), 3),
#  (('quickbase-community.intuit.com', 'english'), 3),
#  (('bangaloremirror.indiatimes.com', 'english'), 3),
#  (('ntp.niehs.nih.gov', 'english'), 3),
#  (('zhengzhou.auto.qq.com', 'english'), 3),
#  (('bollywood.bhaskar.com', 'english'), 3),
#  (('www.cbs.com', 'english'), 3),
#  (('matheducators.stackexchange.com', 'english'), 3),
#  (('www.surveymonkey.com', 'english'), 3),
#  (('freebies.about.com', 'english'), 3),
#  (('albuquerque.craigslist.org', 'english'), 3),
#  (('nanjing.auto.qq.com', 'english'), 3),
#  (('jetswire.usatoday.com', 'english'), 2),
#  (('virgin.craigslist.org', 'english'), 2),
#  (('recipes.latimes.com', 'english'), 2),
#  (('help.aol.com', 'english'), 2),
#  (('planet.mozilla.org', 'english'), 2),
#  (('prezi.com', 'english'), 2),
#  (('philippians314.squarespace.com', 'english'), 2),
#  (('opensource.apple.com', 'english'), 2),
#  (('nccam.nih.gov', 'english'), 2),
#  (('kr.investing.com', 'english'), 2),
#  (('homicide.latimes.com', 'english'), 2),
#  (('cricket.yahoo.com', 'english'), 2),
#  (('hkstylemen.yahoo.com', 'english'), 2),
#  (('email.about.com', 'english'), 2),
#  (('ideas.ted.com', 'english'), 2),
#  (('feeds.cbsnews.com', 'english'), 2),
#  (('goitaly.about.com', 'english'), 2),
#  (('php.net', 'english'), 2),
#  (('feeds.gawker.com', 'english'), 2),
#  (('us.rd.yahoo.com', 'english'), 2),
#  (('philosophy.stackexchange.com', 'english'), 2),
#  (('linguistics.stackexchange.com', 'english'), 2),
#  (('myaccount.nytimes.com', 'english'), 2),
#  (('arts.mit.edu', 'english'), 2),
#  (('www.kayak.com', 'english'), 2),
#  (('es.reuters.com', 'english'), 2),
#  (('feeds.latimes.com', 'english'), 2),
#  (('blender.stackexchange.com', 'english'), 2),
#  (('software.intel.com', 'english'), 2),
#  (('gohongkong.about.com', 'english'), 2),
#  (('www.state.gov', 'english'), 2),
#  (('portables.about.com', 'english'), 2),
#  (('washingtondc.craigslist.org', 'english'), 2),
#  (('boardgames.stackexchange.com', 'english'), 2),
#  (('spanish.xinhuanet.com', 'english'), 2),
#  (('lifehacks.stackexchange.com', 'english'), 2),
#  (('xian.auto.qq.com', 'english'), 2),
#  (('hk.style.yahoo.com', 'english'), 2),
#  (('russian.stackexchange.com', 'english'), 2),
#  (('abclocal.go.com', 'english'), 2),
#  (('developer.mozilla.org', 'english'), 2),
#  (('homestaging.about.com', 'english'), 2),
#  (('ahmedabadmirror.indiatimes.com', 'english'), 2),
#  (('drudgereport.com', 'english'), 2),
#  (('www.ibm.com', 'english'), 2),
#  (('actualidad.rt.com', 'english'), 2),
#  (('anime.stackexchange.com', 'english'), 2),
#  (('www.independent.co.uk', 'english'), 2),
#  (('prod.www.texans.clubs.nfl.com', 'english'), 2),
#  (('baltimore.about.com', 'english'), 2),
#  (('hacks.mozilla.org', 'english'), 2),
#  (('monero.stackexchange.com', 'english'), 2),
#  (('video.fc2.com', 'english'), 2),
#  (('es.vida-estilo.yahoo.com', 'english'), 2),
#  (('slack.com', 'english'), 2),
#  (('espn.uol.com.br', 'english'), 2),
#  (('www.nimh.nih.gov', 'english'), 2),
#  (('broadly.vice.com', 'english'), 2),
#  (('nytlive.nytimes.com', 'english'), 2),
#  (('german.stackexchange.com', 'english'), 2),
#  (('help.issuu.com', 'english'), 2),
#  (('cn.wsj.com', 'english'), 2),
#  (('in.movies.yahoo.com', 'english'), 2),
#  (('mlb.mlb.com', 'english'), 2),
#  (('gardening.stackexchange.com', 'english'), 2),
#  (('ca.celebrity.yahoo.com', 'english'), 2),
#  (('it.sports.yahoo.com', 'english'), 2),
#  (('atlanta.craigslist.org', 'english'), 2),
#  (('taxpayeradvocate.irs.gov', 'english'), 2),
#  (('de.answers.yahoo.com', 'english'), 2),
#  (('grandrapids.craigslist.org', 'english'), 2),
#  (('ar.answers.yahoo.com', 'english'), 2),
#  (('news.samsung.com', 'english'), 2),
#  (('cio.economictimes.indiatimes.com', 'english'), 2),
#  (('www.godaddy.com', 'english'), 2),
#  (('golftravel.about.com', 'english'), 2),
#  (('iotdataplans.att.com', 'english'), 1),
#  (('www2.sdcounty.ca.gov', 'english'), 1),
#  (('m23.sourceforge.net', 'english'), 1),
#  (('treasure.craigslist.org', 'english'), 1),
#  (('press.allrecipes.com', 'english'), 1),
#  (('khabar.ndtv.com', 'english'), 1),
#  (('articles.latimes.com', 'english'), 1),
#  (('cincinnati.reds.mlb.com', 'english'), 1),
#  (('pittsburgh.pirates.mlb.com', 'english'), 1),
#  (('chess.stackexchange.com', 'english'), 1),
#  (('forum.liputan6.com', 'english'), 1),
#  (('ham.stackexchange.com', 'english'), 1),
#  (('ksj.mit.edu', 'english'), 1),
#  (('amylawrence.radio.cbssports.com', 'english'), 1),
#  (('salesforce.stackexchange.com', 'english'), 1),
#  (('rarbg.to', 'english'), 1),
#  (('jacksonville.craigslist.org', 'english'), 1),
#  (('au.lifestyle.yahoo.com', 'english'), 1),
#  (('bucswire.usatoday.com', 'english'), 1),
#  (('bedroom.about.com', 'english'), 1),
#  (('sandiego.about.com', 'english'), 1),
#  (('woodworking.stackexchange.com', 'english'), 1),
#  (('goscandinavia.about.com', 'english'), 1),
#  (('ssl.www8.hp.com', 'english'), 1),
#  (('store.latimes.com', 'english'), 1),
#  (('community.spotify.com', 'english'), 1),
#  (('en.dailypakistan.com.pk', 'english'), 1),
#  (('www.vetogate.com', 'english'), 1),
#  (('mundoestranho.abril.com.br', 'english'), 1),
#  (('pressroom.ups.com', 'english'), 1),
#  (('newsite.thehindu.com', 'english'), 1),
#  (('archive.aweber.com', 'english'), 1),
#  (('kaltim.tribunnews.com', 'english'), 1),
#  (('healthreach.nlm.nih.gov', 'english'), 1),
#  (('www.bre.ca.gov', 'english'), 1),
#  (('brunswick.craigslist.org', 'english'), 1),
#  (('prod.www.steelers.clubs.nfl.com', 'english'), 1),
#  (('partners.wsj.com', 'english'), 1),
#  (('ftlauderdale.backpage.com', 'english'), 1),
#  (('bisnis.liputan6.com', 'english'), 1),
#  (('diy.about.com', 'english'), 1),
#  (('www.myfitnesspal.com', 'english'), 1),
#  (('allrecipes.com', 'english'), 1),
#  (('eurosport.onet.pl', 'english'), 1),
#  (('engineering.stackexchange.com', 'english'), 1),
#  (('madeinstone.squarespace.com', 'english'), 1),
#  (('hinduism.stackexchange.com', 'english'), 1),
#  (('www.mumbaimirror.indiatimes.com', 'english'), 1),
#  (('zenlea.en.alibaba.com', 'english'), 1),
#  (('pittsburgh.craigslist.org', 'english'), 1),
#  (('paidpost.nytimes.com', 'english'), 1),
#  (('v.money.163.com', 'english'), 1),
#  (('favans.quora.com', 'english'), 1),
#  (('earthscience.stackexchange.com', 'english'), 1),
#  (('viewfinder.expedia.com', 'english'), 1),
#  (('mideastfood.about.com', 'english'), 1),
#  (('elliemae.tss01.tbe.taleo.net', 'english'), 1),
#  (('products.office.com', 'english'), 1),
#  (('tools.woot.com', 'english'), 1),
#  (('release.mozilla.org', 'english'), 1),
#  (('usnews.nbcnews.com', 'english'), 1),
#  (('wine.woot.com', 'english'), 1),
#  (('www.nairaland.com', 'english'), 1),
#  (('christianity.stackexchange.com', 'english'), 1),
#  (('e.vnexpress.net', 'english'), 1),
#  (('br.wsj.com', 'english'), 1),
#  (('www.energy.ca.gov', 'english'), 1),
#  (('security-center.intel.com', 'english'), 1),
#  (('th.investing.com', 'english'), 1),
#  (('arabic.cnn.com', 'english'), 1),
#  (('www.6pm.com', 'english'), 1),
#  (('v.news.163.com', 'english'), 1),
#  (('hartford.craigslist.org', 'english'), 1),
#  (('icecream-pdf-splitandmerge.uptodown.com', 'english'), 1),
#  (('m.yenisafak.com', 'english'), 1),
#  (('m6info.yahoo.com', 'english'), 1),
#  (('prod.www.49ers.clubs.nfl.com', 'english'), 1),
#  (('spark.adobe.com', 'english'), 1),
#  (('staging.entertainment.abs-cbn.com', 'english'), 1),
#  (('buffaloniagara.about.com', 'english'), 1),
#  (('gear.lifehacker.com', 'english'), 1),
#  (('www.mozilla.org', 'english'), 1),
#  (('odl.mit.edu', 'english'), 1),
#  (('helpx.adobe.com', 'english'), 1),
#  (('nz.answers.yahoo.com', 'english'), 1),
#  (('vikingswire.usatoday.com', 'english'), 1),
#  (('dolphinswire.usatoday.com', 'english'), 1),
#  (('bloomberg.finanza.repubblica.it', 'english'), 1),
#  (('kidscooking.about.com', 'english'), 1),
#  (('features.faithtap.com', 'english'), 1),
#  (('phoenix.craigslist.org', 'english'), 1),
#  (('sacramento.craigslist.org', 'english'), 1),
#  (('www.scribd.com', 'english'), 1),
#  (('nefactory.web.fc2.com', 'english'), 1),
#  (('utaudatabase.wiki.fc2.com', 'english'), 1),
#  (('www.consilium.europa.eu', 'english'), 1),
#  (('editorial.rottentomatoes.com', 'english'), 1),
#  (('boulder.craigslist.org', 'english'), 1),
#  (('islam.stackexchange.com', 'english'), 1),
#  (('aceh.tribunnews.com', 'english'), 1),
#  (('betterworld.mit.edu', 'english'), 1),
#  (('sdm.mit.edu', 'english'), 1),
#  (('www.cisco.com', 'english'), 1),
#  (('www.thedailybeast.com', 'english'), 1),
#  (('world.chinadaily.com.cn', 'english'), 1),
#  (('www.wattpad.com', 'english'), 1),
#  (('courses.csail.mit.edu', 'english'), 1),
#  (('traveler.marriott.com', 'english'), 1),
#  (('dev.office.com', 'english'), 1),
#  (('law.stackexchange.com', 'english'), 1),
#  (('giantswire.usatoday.com', 'english'), 1),
#  (('framework.latimes.com', 'english'), 1),
#  (('de.nachrichten.yahoo.com', 'english'), 1),
#  (('ramirezsolutions.squarespace.com', 'english'), 1),
#  (('raspberrypi.stackexchange.com', 'english'), 1),
#  (('detroit.craigslist.org', 'english'), 1),
#  (('saltlakecity.about.com', 'english'), 1),
#  (('nei.nih.gov', 'english'), 1),
#  (('etiquette.about.com', 'english'), 1),
#  (('m.food.ndtv.com', 'english'), 1),
#  (('cnnespanol.cnn.com', 'english'), 1),
#  (('realtime.rediff.com', 'english'), 1),
#  (('toxmap.nlm.nih.gov', 'english'), 1),
#  (('waypoint.vice.com', 'english'), 1),
#  (('jobsearch.about.com', 'english'), 1),
#  (('stlouis.craigslist.org', 'english'), 1),
#  (('tv.bt.com', 'english'), 1),
#  (('prod.www.jaguars.clubs.nfl.com', 'english'), 1),
#  (('shop.time.com', 'english'), 1),
#  (('bizcircle.att.com', 'english'), 1),
#  (('www.shutterstock.com', 'english'), 1),
#  (('incoming.shopify.com', 'english'), 1),
#  (('ir.instructure.com', 'english'), 1),
#  (('dariinqq.deviantart.com', 'english'), 1),
#  (('poolandpatio.about.com', 'english'), 1),
#  (('buddhism.stackexchange.com', 'english'), 1),
#  (('eleccioneseeuu2016.yahoo.com', 'english'), 1),
#  (('gojapan.about.com', 'english'), 1),
#  (('minneapolis.craigslist.org', 'english'), 1),
#  (('status.evernote.com', 'english'), 1),
#  (('ncaa.com', 'english'), 1),
#  (('redskinswire.usatoday.com', 'english'), 1),
#  (('www.airbnb.com', 'english'), 1),
#  (('gr.pcmag.com', 'english'), 1),
#  (('egypt.souq.com', 'english'), 1),
#  (('directory-list-print-pro.uptodown.com', 'english'), 1),
#  (('aidsinfo.nih.gov', 'english'), 1),
#  (('securingtomorrow.mcafee.com', 'english'), 1),
#  (('diply.com', 'english'), 1),
#  (('www.qq.com', 'english'), 1),
#  (('nashville.about.com', 'english'), 1),
#  (('712educators.about.com', 'english'), 1),
#  (('it.meteo.yahoo.com', 'english'), 1),
#  (('item.rakuten.co.jp', 'english'), 1),
#  (('breakfast.about.com', 'english'), 1),
#  (('omaha.craigslist.org', 'english'), 1),
#  (('yali.state.gov', 'english'), 1),
#  (('support.xbox.com', 'english'), 1),
#  (('europa.eu', 'english'), 1),
#  ...]

# %% [markdown]
# # Extract the reliable sources

# %%
domains_reliable = ['www.reuters.com', 'www.yahoo.com', 'www.sfgate.com', 'www.chron.com', 'news.yahoo.com',
                    'uk.finance.yahoo.com', 'indianexpress.com', 'www.huffingtonpost.com', 'abcnews.go.com',
                    'www.msn.com', 'www.businessinsider.com', 'uk.reuters.com', 'www.theguardian.com', 
                    'ca.reuters.com', 'www.wsj.com', 'af.reuters.com', 'www.nhl.com', 'www.legacy.com', 
                    'www.latimes.com', 'www.washingtonpost.com', 'sports.yahoo.com', 'www.forbes.com', 
                    'www.nytimes.com', 'www.nydailynews.com', 'www.bloomberg.com', 'in.reuters.com', 
                    'www.usatoday.com', 'www.ndtv.com', 'music.yahoo.com', 'www.cnbc.com', 'ca.news.yahoo.com', 
                    'www.cbsnews.com', 'www.marketwatch.com', 'm.mlb.com', 'nypost.com', 'www.npr.org', 
                    'bleacherreport.com', 'zeenews.india.com', 'finance.yahoo.com', 'feeds.reuters.com', 
                    'www.cbssports.com', 'edition.cnn.com', 'people.com', 'www.cnet.com', 'nz.sports.yahoo.com', 
                    'news.abs-cbn.com', 'www.nba.com', 'online.wsj.com', 'de.finance.yahoo.com','www.investing.com', 
                    'www.cnn.com', 'www.eonline.com', 'newsinfo.inquirer.net', 'www.nbcnews.com', 'www.politico.com', 
                    'profit.ndtv.com', 'wiki.mozilla.org', 'disneyworld.disney.go.com', 'uk.news.yahoo.com', 
                    'video.foxnews.com', 'au.finance.yahoo.com', 'latino.foxnews.com', 'nz.news.yahoo.com', 
                    'www.engadget.com', 'www.vice.com', 'www.wikihow.com', 'money.cnn.com', 'washpost.bloomberg.com', 
                    'au.be.yahoo.com', 'www.realclearpolitics.com', 'motherboard.vice.com', 'au.news.yahoo.com', 
                    'www.nfl.com', 'www.buzzfeed.com', 'www.theatlantic.com', 'www.foxnews.com']

# %%
domains_reliable_set = set(domains_reliable)

# %%
with tqdm() as progress:
    with open('/Volumes/ExternalSSD/FakeNewsRecognition/webhose/raw_reliable.jsonl', 'w') as out_raw_reliable:
        for file in files:
            with open(path + file, 'r') as in_file:
                line = in_file.readlines()[0]
                article = ujson.loads(line)
                domain = article['thread']['site_full']
                if domain in domains_reliable_set:
                    out_raw_reliable.write(ujson.dumps(article) + '\n')

            progress.update()
# Out:
# 499610it [11:07, 747.96it/s]

# %%
urls_sample = []
with tqdm() as progress:
    for file in files:
        with open(path + file, 'r') as in_file:
            line = in_file.readlines()[0]
            article = ujson.loads(line)
            domain = article['thread']['site_full']
            if domain in domains_reliable_set 'www.yahoo.com': # and len(article['text']) > 500: 
                urls_sample.append(article['url'])
                if len(urls_sample) > 100:
                    break
            
        progress.update()
        
article
# Out:
# 2608it [00:03, 722.29it/s]
# {'author': '',
#  'crawled': '2016-11-20T05:19:07.399+02:00',
#  'entities': {'locations': [],
#   'organizations': [{'name': 'getty images', 'sentiment': 'none'}],
#   'persons': [{'name': 'eric mcc', 'sentiment': 'negative'},
#    {'name': 'jane asher', 'sentiment': 'negative'},
#    {'name': 'olivia munn', 'sentiment': 'none'},
#    {'name': 'hailee steinfeld', 'sentiment': 'none'},
#    {'name': 'julianne hough', 'sentiment': 'none'},
#    {'name': 'jon kopaloff/filmmagic gigi hadid', 'sentiment': 'none'},
#    {'name': 'ciara', 'sentiment': 'none'},
#    {'name': 'robert downey jr.', 'sentiment': 'none'},
#    {'name': 'matt bomer', 'sentiment': 'none'},
#    {'name': 'chrissy teigen', 'sentiment': 'none'},
#    {'name': 'nina dobrev', 'sentiment': 'none'},
#    {'name': 'taraji p. henson', 'sentiment': 'none'},
#    {'name': 'janelle monae', 'sentiment': 'none'},
#    {'name': 'laura cavanaugh/filmmagic', 'sentiment': 'none'},
#    {'name': 'karlie kloss', 'sentiment': 'none'},
#    {'name': 'jay pharoah', 'sentiment': 'none'}]},
#  'external_links': [],
#  'highlightText': '',
#  'highlightTitle': '',
#  'language': 'english',
#  'locations': [],
#  'ord_in_thread': 0,
#  'organizations': [],
#  'persons': [],
#  'published': '2016-11-20T00:15:00.000+02:00',
#  'text': "Find Out Who's Presenting at the American Music Awards This Sunday Jane Asher Share Credit: Eric McCandless/ABC via Getty Images; Laura Cavanaugh/FilmMagic; Jon Kopaloff/FilmMagic Gigi Hadid and Jay Pharoah are set to host the 2016 American Music Awards on Sunday, and we are so looking forward to ogling what we're sure will be her many stylish ensembles. And now, we're getting even more excited for the show with a list of confirmed presenters for the night, all of whom will add some serious star power to the already celeb-filled show. Robert Downey Jr. , Taraji P. Henson , Ciara , Julianne Hough , Matt Bomer , Nina Dobrev , Janelle Monae , Olivia Munn , Chrissy Teigen , Hailee Steinfeld , and Karlie Kloss will all be taking the stage as presenters for the night, giving out awards to the lucky winners in categories like Artist of the Year, Tour of the Year, and Video of the Year. VIDEO: Meet the 2016 American Music Award Nominees 5164047872001",
#  'thread': {'country': 'US',
#   'domain_rank': 5,
#   'main_image': 'https://s.yimg.com/uu/api/res/1.2/u3PGlFhA1miOy27nm.QcsQ--/aD0zNTA7dz02MjI7c209MTthcHBpZD15dGFjaHlvbg--/http://media.zenfs.com/en-US/homerun/instyle_846/71f3fe9eecfbb307ed31d57c89c89da2',
#   'participants_count': 0,
#   'performance_score': 0,
#   'published': '2016-11-20T00:15:00.000+02:00',
#   'replies_count': 0,
#   'section_title': 'Fashion and lifestyle News - Yahoo Style Canada',
#   'site': 'yahoo.com',
#   'site_full': 'www.yahoo.com',
#   'site_section': 'https://ca.style.yahoo.com/rss',
#   'site_type': 'news',
#   'social': {'facebook': {'comments': 0, 'likes': 0, 'shares': 0},
#    'gplus': {'shares': 0},
#    'linkedin': {'shares': 0},
#    'pinterest': {'shares': 0},
#    'stumbledupon': {'shares': 0},
#    'vk': {'shares': 0}},
#   'spam_score': 0.0,
#   'title': "Find Out Who's Presenting at the American Music Awards This Sunday",
#   'title_full': "Find Out Who's Presenting at the American Music Awards This Sunday",
#   'url': 'https://www.yahoo.com/style/whos-presenting-american-music-awards-171500473.html',
#   'uuid': '3b081a908aa1b583f0c7b8faf008a2d0092583f2'},
#  'title': "Find Out Who's Presenting at the American Music Awards This Sunday",
#  'url': 'https://www.yahoo.com/style/whos-presenting-american-music-awards-171500473.html',
#  'uuid': '3b081a908aa1b583f0c7b8faf008a2d0092583f2'}

# %%
urls_sample
# Out:
# ['https://www.yahoo.com/news/britains-hull-grabs-lpga-tour-championship-lead-212834416--golf.html?ref=gs',
#  'https://www.yahoo.com/tv/ruffled-trump-tweets-finger-wagging-174508165.html',
#  'https://www.yahoo.com/music/ad-rock-joins-beastie-boys-203447300.html',
#  'https://www.yahoo.com/news/melania-trump-not-moving-into-white-house-in-january-reports-181652896.html',
#  'https://www.yahoo.com/news/haitians-vote-hoping-restore-constitutional-order-144522833.html?ref=gs',
#  'https://www.yahoo.com/tv/saturday-night-live-ratings-dip-171057604.html',
#  'https://www.yahoo.com/news/poacher-costa-sends-chelsea-top-table-183702470--sow.html?ref=gs',
#  'https://www.yahoo.com/news/insigne-ends-goal-drought-brace-napolis-2-1-193341434.html?ref=gs',
#  'https://www.yahoo.com/style/3-moves-guarantee-super-sexy-173002306.html',
#  'https://www.yahoo.com/news/sweet-charity-theater-review-sutton-foster-galumphs-her-221450520.html',
#  'https://www.yahoo.com/style/amazon-package-x-ray-going-184009116.html',
#  'https://www.yahoo.com/news/15-missing-vietnamese-freighter-hits-indonesian-boat-053434974.html',
#  'https://www.yahoo.com/news/cruz-bardem-star-farhadi-film-132850732.html?ref=gs',
#  'https://www.yahoo.com/movies/dwayne-johnson-doubles-down-candy-ass-rant-fast-004513150.html',
#  'https://www.yahoo.com/news/south-africas-opposition-parties-urge-zuma-report-corruption-125835160.html?ref=gs',
#  'https://www.yahoo.com/news/german-neo-nazi-convicted-holocaust-denial-again-174355061.html?ref=gs',
#  'https://www.yahoo.com/news/3-bidders-running-sale-germanys-114948056.html?ref=gs',
#  'https://www.yahoo.com/news/stranded-trucks-unpaid-workers-india-inc-counts-cost-023508905.html?ref=gs',
#  'https://www.yahoo.com/news/john-daly-unretires-pursue-2018-olympic-skeleton-spot-184501627.html?ref=gs',
#  'https://www.yahoo.com/news/facebook-ceo-preaches-connectivity-gospel-145037063.html',
#  'https://www.yahoo.com/style/thanksgiving-leftover-idea-sweet-potato-230353279.html',
#  'https://www.yahoo.com/style/turkey-thanksgiving-still-vegetarian-222959223.html',
#  'https://www.yahoo.com/news/less-ice-world-now-november-192600344.html',
#  'https://www.yahoo.com/news/hughes-keeps-poise-lead-sea-island-220326639.html?ref=gs',
#  'https://www.yahoo.com/news/mexico-arrests-alleged-cartel-assassin-leader-acapulco-213259211.html?ref=gs',
#  'https://www.yahoo.com/news/u-wants-u-n-blacklist-south-sudans-machar-173349824.html',
#  'https://www.yahoo.com/news/trump-meets-former-rival-romney-possible-contender-top-193548655.html?ref=gs',
#  'https://www.yahoo.com/music/chance-rapper-cancelled-remaining-dates-141428958.html',
#  'https://www.yahoo.com/style/app-lets-check-airport-security-233537188.html',
#  'https://www.yahoo.com/news/australias-bizarre-outbreak-thunderstorm-asthma-222200508.html?ref=gs',
#  'https://www.yahoo.com/news/tennessee-crash-revives-debate-over-school-bus-seat-051636355.html',
#  'https://www.yahoo.com/news/santander-abandons-r3-blockchain-consortium-150410248.html?ref=gs',
#  'https://www.yahoo.com/news/why-fewer-americans-want-lose-222300430.html?ref=gs',
#  'https://www.yahoo.com/news/snl-brooklynites-run-real-world-hiding-bubble-054013112.html',
#  'https://www.yahoo.com/style/disney-collaboration-pure-magic-230000267.html',
#  'https://www.yahoo.com/style/couple-recreates-iconic-movie-scenes-221457751.html',
#  'https://www.yahoo.com/style/travel-just-prince-william-kate-170000249.html',
#  'https://www.yahoo.com/news/china-watching-trump-policies-defend-trade-rights-214923430--finance.html?ref=gs',
#  'https://www.yahoo.com/style/spice-girls-song-leaked-everything-224929931.html',
#  'https://www.yahoo.com/news/court-halts-overtime-rule-leaving-023100263.html?ref=gs',
#  'https://www.yahoo.com/style/trailer-andrew-garfield-adam-driver-213141276.html',
#  'https://www.yahoo.com/news/messi-double-guides-barcelona-2-0-win-celtic-214313349.html?ref=gs',
#  'https://www.yahoo.com/news/hundreds-nostalgic-franco-dictatorship-rally-madrid-142614961.html?ref=gs',
#  'https://www.yahoo.com/tv/president-elect-donald-trump-versus-181915695.html',
#  'https://www.yahoo.com/news/meeting-putin-philippines-duterte-rails-western-hypocrisy-070056134.html?ref=gs',
#  'https://www.yahoo.com/style/somebody-recut-iron-man-trailer-172653379.html',
#  'https://www.yahoo.com/style/snl-sketch-finally-confirmed-worst-180650973.html',
#  'https://www.yahoo.com/style/arctic-ice-crazy-low-now-191336194.html',
#  'https://www.yahoo.com/news/senior-u-officials-recommend-removal-nsa-director-sources-205531651.html',
#  'https://www.yahoo.com/news/hat-trick-no-one-better-ronaldo-madrid-derby-170858653.html?ref=gs',
#  'https://www.yahoo.com/news/foley-scores-15-points-australia-beats-france-25-221407847.html?ref=gs',
#  'https://www.yahoo.com/style/kate-hudson-got-epically-gushy-170831275.html',
#  'https://www.yahoo.com/style/beauty-gifts-totally-worth-splurge-173000081.html',
#  'https://www.yahoo.com/style/meghan-markle-posted-perfect-tweet-181128680.html',
#  'https://www.yahoo.com/style/bed-101-sheets-pillows-shop-120000662.html',
#  'https://www.yahoo.com/news/15-missing-vietnamese-freighter-hits-indonesian-boat-053434974.html?ref=gs',
#  'https://www.yahoo.com/music/steven-van-zandt-calls-hamilton-201824853.html',
#  'https://www.yahoo.com/news/fantastic-beasts-spins-magic-billy-lynns-tanks-165006700.html?ref=gs',
#  'https://www.yahoo.com/news/check-won-powerball-jackpot-031913824.html',
#  'https://www.yahoo.com/news/tsunami-warning-issued-quake-off-fukushima-japan-212030030.html?ref=gs',
#  'https://www.yahoo.com/music/heres-why-kanye-west-canceled-172201591.html',
#  'https://www.yahoo.com/news/du-plessis-face-ball-tampering-hearing-tuesdya-200746340.html?ref=gs',
#  'https://www.yahoo.com/news/276416-212033426.html',
#  'http://www.yahoo.com/celebrity/snoop-dogg-is-all-of-us-watching-kanye-wests-bizarre-stage-rant-192326478.html',
#  'https://www.yahoo.com/news/u-says-russian-deployment-missiles-destabilizing-europe-202903829.html?ref=gs',
#  'https://www.yahoo.com/tv/emma-stone-host-saturday-night-052637640.html',
#  'https://www.yahoo.com/news/advanced-weather-satellite-launch-space-210648861.html?ref=gs',
#  'https://www.yahoo.com/news/2nd-day-trump-demands-apology-cast-hamilton-142250381.html?ref=gs',
#  'https://www.yahoo.com/news/haiti-holds-long-awaited-vote-still-reeling-hurricane-080455095.html?ref=gs',
#  'https://www.yahoo.com/news/ultimate-holiday-tipping-guide-160623621.html',
#  'https://www.yahoo.com/news/peabody-debt-dispute-fizzles-coal-prices-rise-215450284--sector.html?ref=gs',
#  'https://www.yahoo.com/news/no-20-baylor-holds-off-vcu-71-63-215141583.html?ref=gs',
#  'https://www.yahoo.com/beauty/10-liquid-eyeliners-finally-help-195940819.html',
#  'https://www.yahoo.com/news/uk-cuts-growth-forecasts-first-budget-plan-since-124917002--business.html?ref=gs',
#  'https://www.yahoo.com/tv/jessica-simpsons-kids-look-little-223200366.html',
#  'https://www.yahoo.com/tech/worst-thing-macbook-pro-non-replaceable-ssd-234949077.html',
#  'https://www.yahoo.com/celebrity/liam-hemsworth-spoils-miley-cyrus-for-her-birthday-205701489.html',
#  'https://www.yahoo.com/movies/notes-on-blindness-into-darkness-we-give-new-documentarys-vr-companion-a-try-210210170.html',
#  'https://www.yahoo.com/music/thanksgiving-songs-music-about-food-giving-thanks-and-the-holiday-235717530.html',
#  'https://www.yahoo.com/news/updated-sabra-recalls-hummus-nationwide-163336782.html',
#  'http://www.yahoo.com/celebrity/kylie-jenner-celebrates-tygas-birthday-192900901.html',
#  'https://www.yahoo.com/news/trump-meets-king-hollywood-ari-emanuel-201426710.html',
#  'https://www.yahoo.com/news/belgian-lab-scientists-search-perfect-beer-yeast-155123074.html',
#  'https://www.yahoo.com/style/blac-chyna-shows-off-her-160000832.html',
#  'https://www.yahoo.com/news/16-killed-senegal-pilgrimage-road-accidents-195859993.html',
#  'https://www.yahoo.com/news/merkel-expected-she-seek-fourth-term-german-chancellor-115405388.html?ref=gs',
#  'https://www.yahoo.com/tv/janet-jackson-breaks-social-media-023200185.html',
#  'https://www.yahoo.com/news/zealand-beats-pakistan-8-wickets-1st-test-020052322.html?ref=gs',
#  'https://www.yahoo.com/style/janet-jackson-just-gave-pregnancy-202314239.html',
#  'https://www.yahoo.com/news/philippines-duterte-meets-hero-putin-013539200.html',
#  'https://www.yahoo.com/tech/apple-reportedly-throttling-verizon-iphone-120000534.html',
#  'https://www.yahoo.com/news/uk-treasury-chief-brexit-uncertainty-123553432.html?ref=gs',
#  'https://www.yahoo.com/news/death-toll-northern-india-train-derailment-jumps-63-051000146.html',
#  'https://www.yahoo.com/news/obama-tells-latin-america-world-trump-time-dont-061355839.html?ref=gs',
#  'https://www.yahoo.com/news/rwanda-catholic-bishops-apologize-role-genocide-194620433.html?ref=gs',
#  'https://www.yahoo.com/news/jones-puts-boot-wales-japan-scare-004124426.html?ref=gs',
#  'https://www.yahoo.com/style/blake-lively-totally-lost-her-174500788.html',
#  'https://www.yahoo.com/news/senior-u-officials-recommend-removal-nsa-director-sources-012850051.html',
#  'https://www.yahoo.com/news/haitians-vote-hoping-restore-constitutional-order-072011711.html?ref=gs',
#  'https://www.yahoo.com/style/playful-interview-between-emma-roberts-004936931.html',
#  'https://www.yahoo.com/style/whos-presenting-american-music-awards-171500473.html']

# %%
len(article['text'])
# Out:
# 412

# %% [markdown]
# # Insert webhose to standard Page DB format

# %%
peewee_database_webhose = SqliteDatabase(path_data + 'webhose/news_cleaned_webhose.db')
Page._meta.database = peewee_database_webhose
Page.create_table()

# %%
batch_size = 50
pages_to_insert = []
with tqdm() as progress:
    with open('/Volumes/ExternalSSD/FakeNewsRecognition/webhose/raw_reliable.jsonl', 'r') as in_raw_reliable:
        for line in in_raw_reliable:
            article = ujson.loads(line)
            pages_to_insert.append({
                'scraped_page_id': 0,
                'batch': 0,
                'domain': article['thread']['site_full'],
                'type': 'reliable',
                'url': article['url'],
                'content': article['text'],
                'scraped_at': article['crawled'],
                'title': article['title'],
                'authors': article['author']
            })
            progress.update()
            
            if len(pages_to_insert) >= batch_size:
                with peewee_database_webhose.atomic():
                    Page.insert_many(pages_to_insert).execute()
                    pages_to_insert = []
            
with peewee_database_webhose.atomic():
    Page.insert_many(pages_to_insert).execute()
    pages_to_insert = []
# Out:
# 342351it [03:20, 1706.87it/s]
