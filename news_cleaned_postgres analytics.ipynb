# %%
import pandas as pd
from tqdm import tqdm
from peewee import SqliteDatabase, fn
from playhouse.shortcuts import model_to_dict

from database import Page

# %%
path_data = '/Volumes/ExternalSSD/FakeNewsRecognition/'
peewee_database_postgres = SqliteDatabase(path_data + 'news_cleaned_postgres.db')
peewee_database_2018_01_29_and_postgres = SqliteDatabase(path_data + 'news_cleaned_2018_01_29+postgres.db')
peewee_database_2018_02_13  = SqliteDatabase(path_data + 'news_cleaned_2018_01_29+postgres+nytimes+webhose.db')

# %%
Page._meta.database = peewee_database_2018_02_13
Page.select(fn.Max(Page.id)).scalar()
# Out:
# 9878296

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Analytics" data-toc-modified-id="Analytics-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Analytics</a></span></li><li><span><a href="#Merge-news_cleaned_2018_01_29-with-news_cleaned_postgres" data-toc-modified-id="Merge-news_cleaned_2018_01_29-with-news_cleaned_postgres-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Merge news_cleaned_2018_01_29 with news_cleaned_postgres</a></span></li></ul></div>

# %% [markdown]
# # Analytics

# %%
def fetch_pages(last_id, batch_size, db):
    while True:
        Page._meta.database = db
        db.connect(reuse_if_open=True)
        
        pages = list(Page.select(Page.id, Page.domain)
                     .where((Page.id > last_id) & (Page.id <= (last_id + batch_size)))
                     .order_by(Page.id.asc()))

        if len(pages) <= 0:
            return

        for page in pages:
            yield page

            last_id = page.id

# %%
domains_counter = {}
with tqdm() as progress:
    for page in fetch_pages(0, 10 * 1000, peewee_database_2018_02_13):
        domains_counter.setdefault(page.domain, 0)
        domains_counter[page.domain] += 1
        progress.update()
# Out:
# 9878296it [33:04, 4977.47it/s]

# %%
domains_counter_list = list(domains_counter.items())
domains_counter_sorted = sorted(domains_counter_list, key=lambda x: x[1], reverse=True)
domains_counter_sorted
# Out:
# [('nytimes.com', 1542967),
#  ('dailykos.com', 1088536),
#  ('beforeitsnews.com', 783308),
#  ('nationalreview.com', 484009),
#  ('express.co.uk', 477681),
#  ('sputniknews.com', 320057),
#  ('abovetopsecret.com', 238640),
#  ('wikileaks.org', 199553),
#  ('pjmedia.com', 140003),
#  ('www.newsmax.com', 113766),
#  ('pravda.ru', 104717),
#  ('www.ammoland.com', 93863),
#  ('wikispooks.com', 86995),
#  ('www.amazon.com', 83227),
#  ('lifezette.com', 82998),
#  ('twitchy.com', 81575),
#  ('katehon.com', 75923),
#  ('dailycaller.com', 74320),
#  ('investmentwatchblog.com', 71391),
#  ('naturalnews.com', 70292),
#  ('breitbart.com', 65678),
#  ('rawstory.com', 62463),
#  ('thepostemail.com', 61029),
#  ('conservapedia.com', 56595),
#  ('presstv.com', 54513),
#  ('lifenews.com', 53524),
#  ('thedailysheeple.com', 52712),
#  ('us.blastingnews.com', 50825),
#  ('truthandaction.org', 49205),
#  ('unz.com', 48434),
#  ('zerohedge.com', 47694),
#  ('liberalamerica.org', 46730),
#  ('washingtonexaminer.com', 46683),
#  ('thesleuthjournal.com', 46366),
#  ('thinkprogress.org', 45510),
#  ('truthbroadcastnetwork.com', 44298),
#  ('rinf.com', 44044),
#  ('amren.com', 41814),
#  ('thelibertybeacon.com', 38745),
#  ('lifesitenews.com', 38386),
#  ('newstarget.com', 38167),
#  ('observer.com', 37345),
#  ('truthfeed.com', 36911),
#  ('judicialwatch.org', 36384),
#  ('thephaser.com', 36159),
#  ('lewrockwell.com', 35662),
#  ('awarenessact.com', 35081),
#  ('patriotpost.us', 34582),
#  ('thenet24h.com', 34012),
#  ('www.reuters.com', 33991),
#  ('therussophile.org', 33646),
#  ('shadowproof.com', 31525),
#  ('americanthinker.com', 31497),
#  ('redstate.com', 30994),
#  ('opednews.com', 30863),
#  ('americablog.com', 28281),
#  ('mintpressnews.com', 28215),
#  ('weeklystandard.com', 28063),
#  ('teapartytribune.com', 27653),
#  ('www.freedomsphoenix.com', 26821),
#  ('activistpost.com', 26648),
#  ('conservativerefocus.com', 26468),
#  ('thenewamerican.com', 26216),
#  ('chroniclesmagazine.org', 25796),
#  ('fellowshipoftheminds.com', 24863),
#  ('threepercenternation.com', 24828),
#  ('theduran.com', 24800),
#  ('truepundit.com', 24605),
#  ('21stcenturywire.com', 24415),
#  ('thesaker.is', 23876),
#  ('thedailymash.co.uk', 23083),
#  ('truthrevolt.org', 22461),
#  ('www.yahoo.com', 22454),
#  ('www.sfgate.com', 22281),
#  ('thepeoplescube.com', 21813),
#  ('christianpost.com', 20070),
#  ('alternet.org', 19757),
#  ('www.chron.com', 18532),
#  ('naturalnewsblogs.com', 18308),
#  ('thefifthcolumnnews.com', 18130),
#  ('theconservativetreehouse.com', 18097),
#  ('libertyunyielding.com', 18082),
#  ('vdare.com', 17891),
#  ('flyheight.com', 17088),
#  ('theeventchronicle.com', 16947),
#  ('news.yahoo.com', 16755),
#  ('www.eutimes.net', 16540),
#  ('morningnewsusa.com', 14885),
#  ('jackpineradicals.com', 14821),
#  ('theonion.com', 14717),
#  ('politicususa.com', 14299),
#  ('thefederalistpapers.org', 14217),
#  ('conservativepapers.com', 13999),
#  ('jihadwatch.org', 13955),
#  ('freebeacon.com', 13920),
#  ('shoebat.com', 13413),
#  ('theinternetpost.net', 13393),
#  ('conservativetribune.com', 13054),
#  ('veteranstoday.com', 13031),
#  ('coed.com', 13017),
#  ('darkpolitricks.com', 12928),
#  ('thedailybeast.com', 12909),
#  ('uk.finance.yahoo.com', 12715),
#  ('morningledger.com', 12657),
#  ('rense.com', 12476),
#  ('frontpagemag.com', 12318),
#  ('themuslimissue.wordpress.com', 12249),
#  ('www.occupy.com', 12122),
#  ('guardianlv.com', 12115),
#  ('indianexpress.com', 11672),
#  ('thirdworldtraveler.com', 11302),
#  ('infiniteunknown.net', 10960),
#  ('www.huffingtonpost.com', 10939),
#  ('collectivelyconscious.net', 10765),
#  ('commondreams.org', 10688),
#  ('yournewswire.com', 10678),
#  ('familysecuritymatters.org', 10657),
#  ('theeconomiccollapseblog.com', 10625),
#  ('www.greenmedinfo.com', 10569),
#  ('commentarymagazine.com', 10417),
#  ('americankabuki.blogspot.com', 10326),
#  ('pravdareport.com', 9745),
#  ('wnd.com', 9712),
#  ('americanfreepress.net', 9511),
#  ('baptistnews.com', 9425),
#  ('thefreepatriot.org', 9360),
#  ('thehardtimes.net', 9305),
#  ('pamelageller.com', 9304),
#  ('thedailycoin.org', 9193),
#  ('nakedcapitalism.com', 8987),
#  ('jacobinmag.com', 8924),
#  ('wikileaks.com', 8864),
#  ('abcnews.go.com', 8657),
#  ('powerlineblog.com', 8548),
#  ('ancient-code.com', 8500),
#  ('canadafreepress.com', 8493),
#  ('realfarmacy.com', 8208),
#  ('breaking911.com', 8189),
#  ('conservativehq.com', 8098),
#  ('consortiumnews.com', 7957),
#  ('www.trueactivist.com', 7951),
#  ('dailysignal.com', 7720),
#  ('thefreethoughtproject.com', 7663),
#  ('www.msn.com', 7629),
#  ('advocate.com', 7574),
#  ('libertynews.com', 7459),
#  ('centerforsecuritypolicy.org', 7394),
#  ('americanlookout.com', 7281),
#  ('countercurrents.org', 7234),
#  ('southfront.org', 7026),
#  ('shiftfrequency.com', 6962),
#  ('thegatewaypundit.com', 6937),
#  ('nutritionfacts.org', 6794),
#  ('www.businessinsider.com', 6681),
#  ('rightwingnews.com', 6669),
#  ('antiwar.com', 6649),
#  ('uk.reuters.com', 6574),
#  ('russia-insider.com', 6506),
#  ('returnofkings.com', 6485),
#  ('dcclothesline.com', 6389),
#  ('www.theguardian.com', 6370),
#  ('breakpoint.org', 6206),
#  ('anonhq.com', 6164),
#  ('coasttocoastam.com', 6160),
#  ('americankabuki.blogspot.ie', 6144),
#  ('willyloman.wordpress.com', 6094),
#  ('newswithviews.com', 5981),
#  ('therebel.media', 5874),
#  ('counterpunch.org', 5807),
#  ('disclose.tv', 5805),
#  ('ca.reuters.com', 5771),
#  ('nationalvanguard.org', 5684),
#  ('freedomoutpost.com', 5673),
#  ('www.wsj.com', 5550),
#  ('tyronetribulations.com', 5490),
#  ('freedomworks.org', 5445),
#  ('4threvolutionarywar.wordpress.com', 5424),
#  ('af.reuters.com', 5416),
#  ('www.nhl.com', 5378),
#  ('icr.org', 5354),
#  ('www.legacy.com', 5301),
#  ('thespoof.com', 5191),
#  ('www.latimes.com', 5167),
#  ('trueeconomics.blogspot.com', 5085),
#  ('www.washingtonpost.com', 5074),
#  ('elitereaders.com', 5072),
#  ('sports.yahoo.com', 5057),
#  ('ecowatch.com', 4996),
#  ('tenthamendmentcenter.com', 4952),
#  ('www.forbes.com', 4933),
#  ('toprightnews.com', 4917),
#  ('wakingtimes.com', 4786),
#  ('dailywire.com', 4731),
#  ('educate-yourself.org', 4719),
#  ('itmakessenseblog.com', 4693),
#  ('www.cnsnews.com', 4682),
#  ('cnnnext.com', 4628),
#  ('readynutrition.com', 4577),
#  ('www.nytimes.com', 4557),
#  ('infowars.com', 4520),
#  ('dissentmagazine.org', 4499),
#  ('drrichswier.com', 4498),
#  ('thetruthdivision.com', 4496),
#  ('dennismichaellynch.com', 4347),
#  ('americantoday.news', 4299),
#  ('americanprogress.org', 4294),
#  ('orientalreview.org', 4241),
#  ('www.nydailynews.com', 4175),
#  ('www.bloomberg.com', 4159),
#  ('oathkeepers.org', 4103),
#  ('in.reuters.com', 4083),
#  ('www.usatoday.com', 4075),
#  ('kingworldnews.com', 4041),
#  ('www.ndtv.com', 3966),
#  ('sott.net', 3931),
#  ('wearechange.org', 3912),
#  ('barnesreview.org', 3906),
#  ('westernjournalism.com', 3887),
#  ('gulagbound.com', 3870),
#  ('politicops.com', 3815),
#  ('music.yahoo.com', 3787),
#  ('randpaulreview.com', 3735),
#  ('thegoldwater.com', 3724),
#  ('themindunleashed.com', 3633),
#  ('washingtonsblog.com', 3611),
#  ('www.cnbc.com', 3589),
#  ('naturalblaze.com', 3584),
#  ('therightscoop.com', 3538),
#  ('realnewsrightnow.com', 3447),
#  ('veteransnewsnow.com', 3446),
#  ('www.emptywheel.net', 3423),
#  ('prisonplanet.com', 3397),
#  ('counterpsyops.com', 3350),
#  ('ca.news.yahoo.com', 3349),
#  ('charismanews.com', 3315),
#  ('tragedyandhope.com', 3297),
#  ('theblaze.com', 3294),
#  ('endoftheamericandream.com', 3277),
#  ('www.cbsnews.com', 3255),
#  ('heritage.org', 3248),
#  ('tribunist.com', 3247),
#  ('healthimpactnews.com', 3245),
#  ('www.marketwatch.com', 3177),
#  ('publicintelligence.net', 3162),
#  ('www.alt-market.com', 3148),
#  ('survivalblog.com', 3105),
#  ('m.mlb.com', 3061),
#  ('nypost.com', 3047),
#  ('thedailywtf.com', 2985),
#  ('politicalblindspot.com', 2982),
#  ('thevictoryreport.org', 2962),
#  ('truthkings.com', 2876),
#  ('jesus-is-savior.com', 2873),
#  ('actualidadpanamericana.com', 2840),
#  ('neonnettle.com', 2833),
#  ('in5d.com', 2813),
#  ('www.npr.org', 2742),
#  ('unionleader.com', 2719),
#  ('www.silverdoctors.com', 2716),
#  ('bleacherreport.com', 2690),
#  ('ifyouonlynews.com', 2687),
#  ('clashdaily.com', 2672),
#  ('zeenews.india.com', 2672),
#  ('moonofalabama.org', 2658),
#  ('truthingold.com', 2655),
#  ('newslo.com', 2629),
#  ('ahtribune.com', 2577),
#  ('theintercept.com', 2567),
#  ('truthstreammedia.com', 2539),
#  ('corbettreport.com', 2533),
#  ('70news.wordpress.com', 2527),
#  ('ironictimes.com', 2477),
#  ('finance.yahoo.com', 2451),
#  ('politicalcult.com', 2425),
#  ('journal-neo.org', 2398),
#  ('projectveritas.com', 2356),
#  ('wolfstreet.com', 2345),
#  ('investmentresearchdynamics.com', 2327),
#  ('feeds.reuters.com', 2306),
#  ('www.cbssports.com', 2298),
#  ('rickwells.us', 2291),
#  ('greanvillepost.com', 2289),
#  ('edition.cnn.com', 2285),
#  ('conservativefiringline.com', 2224),
#  ('people.com', 2223),
#  ('www.cnet.com', 2182),
#  ('policyreview.info', 2164),
#  ('nz.sports.yahoo.com', 2063),
#  ('economicnoise.com', 2043),
#  ('usdefensewatch.com', 2014),
#  ('counterinformation.wordpress.com', 1991),
#  ('theorganicprepper.ca', 1945),
#  ('news.abs-cbn.com', 1943),
#  ('barenakedislam.com', 1933),
#  ('x22report.com', 1927),
#  ('freedomdaily.com', 1916),
#  ('eyeopening.info', 1907),
#  ('collective-evolution.com', 1904),
#  ('www.nba.com', 1896),
#  ('strategic-culture.org', 1874),
#  ('oann.com', 1833),
#  ('eaglerising.com', 1815),
#  ('online.wsj.com', 1810),
#  ('themideastbeast.com', 1799),
#  ('usherald.com', 1781),
#  ('de.finance.yahoo.com', 1746),
#  ('gomerblog.com', 1733),
#  ('www.investing.com', 1731),
#  ('www.cnn.com', 1728),
#  ('americasfreedomfighters.com', 1721),
#  ('www.eonline.com', 1718),
#  ('shtfplan.com', 1714),
#  ('thepoliticalinsider.com', 1692),
#  ('ijr.com', 1667),
#  ('city-journal.org', 1667),
#  ('newsinfo.inquirer.net', 1614),
#  ('thetruthwins.com', 1614),
#  ('whatreallyhappened.com', 1605),
#  ('www.nbcnews.com', 1586),
#  ('www.politico.com', 1581),
#  ('russia-direct.org', 1556),
#  ('mrc.org', 1541),
#  ('ncscooper.com', 1533),
#  ('oftwominds.com', 1508),
#  ('dcgazette.com', 1503),
#  ('paulcraigroberts.org', 1501),
#  ('theantimedia.org', 1490),
#  ('profit.ndtv.com', 1486),
#  ('conservativeoutfitters.com', 1481),
#  ('anonews.co', 1478),
#  ('fromthetrenchesworldreport.com', 1475),
#  ('wiki.mozilla.org', 1474),
#  ('conservativereview.com', 1472),
#  ('occupydemocrats.com', 1446),
#  ('therightstuff.biz', 1446),
#  ('usasupreme.com', 1443),
#  ('disneyworld.disney.go.com', 1440),
#  ('uk.news.yahoo.com', 1425),
#  ('weeklyworldnews.com', 1424),
#  ('humortimes.com', 1381),
#  ('thetruthaboutcancer.com', 1334),
#  ('aanirfan.blogspot.co.uk', 1333),
#  ('rbth.com', 1327),
#  ('endingthefed.com', 1293),
#  ('video.foxnews.com', 1285),
#  ('policestateusa.com', 1284),
#  ('off-guardian.org', 1284),
#  ('informationclearinghouse.info', 1283),
#  ('surenews.com', 1272),
#  ('fridaymash.com', 1271),
#  ('alt-market.com', 1238),
#  ('fusion.net', 1237),
#  ('resistancereport.com', 1185),
#  ('openmagazines.com', 1181),
#  ('teaparty.org', 1142),
#  ('tomwoods.com', 1100),
#  ('chronicle.su', 1091),
#  ('undergroundhealth.com', 1083),
#  ('au.finance.yahoo.com', 1081),
#  ('galacticconnection.com', 1077),
#  ('thenewinquiry.com', 1067),
#  ('deadlyclear.wordpress.com', 1060),
#  ('empirenews.net', 1051),
#  ('patriotchronicle.com', 1030),
#  ('latino.foxnews.com', 1010),
#  ('foodbabe.com', 1002),
#  ('revolutions2040.com', 991),
#  ('thecommonsenseshow.com', 979),
#  ('defenddemocracy.press', 978),
#  ('nz.news.yahoo.com', 967),
#  ('worldnewsdailyreport.com', 966),
#  ('madworldnews.com', 965),
#  ('www.engadget.com', 965),
#  ('ronpaulinstitute.org', 948),
#  ('blackagendareport.com', 945),
#  ('dailysquib.co.uk', 935),
#  ('www.vice.com', 933),
#  ('intellihub.com', 921),
#  ('cowgernation.com', 918),
#  ('kauilapele.wordpress.com', 918),
#  ('bluenationreview.com', 917),
#  ('www.wikihow.com', 914),
#  ('enduringvision.com', 905),
#  ('politicot.com', 902),
#  ('foreignpolicyjournal.com', 891),
#  ('nationalufocenter.com', 883),
#  ('landoverbaptist.org', 881),
#  ('chaser.com.au', 874),
#  ('ewao.com', 857),
#  ('money.cnn.com', 843),
#  ('qpolitical.com', 837),
#  ('shareblue.com', 825),
#  ('prntly.com', 823),
#  ('knowledgeoftoday.org', 816),
#  ('washpost.bloomberg.com', 809),
#  ('survivopedia.com', 807),
#  ('bb4sp.com', 804),
#  ('ushealthyadvisor.com', 804),
#  ('henrymakow.com', 794),
#  ('endtime.com', 791),
#  ('thebricspost.com', 785),
#  ('empiresports.co', 780),
#  ('humansarefree.com', 777),
#  ('au.be.yahoo.com', 767),
#  ('ihr.org', 746),
#  ('www.realclearpolitics.com', 739),
#  ('davidduke.com', 722),
#  ('secretsofthefed.com', 711),
#  ('whatdoesitmean.com', 707),
#  ('itccs.org', 690),
#  ('conservativedailypost.com', 684),
#  ('healthnutnews.com', 680),
#  ('motherboard.vice.com', 657),
#  ('www.sovereignman.com', 651),
#  ('glossynews.com', 650),
#  ('au.news.yahoo.com', 643),
#  ('waterfordwhispersnews.com', 640),
#  ('www.nfl.com', 628),
#  ('whowhatwhy.org', 624),
#  ('www.buzzfeed.com', 620),
#  ('offgridsurvival.com', 620),
#  ('heartland.org', 617),
#  ('williambanzai7.blogspot.com', 612),
#  ('www.theatlantic.com', 612),
#  ('thenewsdoctors.com', 612),
#  ('www.foxnews.com', 611),
#  ('theineptowl.com', 594),
#  ('politicalsitenews.com', 586),
#  ('usapoliticstoday.com', 573),
#  ('celebtricity.com', 563),
#  ('prepperwebsite.com', 548),
#  ('nowtheendbegins.com', 539),
#  ('liberalbias.com', 525),
#  ('addictinginfo.org', 509),
#  ('der-postillon.com', 494),
#  ('weaselzippers.us', 488),
#  ('thrivemovement.com', 478),
#  ('thedailybell.com', 477),
#  ('darkmoon.me', 474),
#  ('viralliberty.com', 474),
#  ('vigilantcitizen.com', 467),
#  ('newsmutiny.com', 467),
#  ('theshovel.com.au', 457),
#  ('allnewspipeline.com', 438),
#  ('newsfrompolitics.com', 426),
#  ('intrepidreport.com', 425),
#  ('21wire.tv', 416),
#  ('thelastgreatstand.com', 406),
#  ('lovethispic.com', 404),
#  ('wallstreetonparade.com', 395),
#  ('americanborderpatrol.com', 384),
#  ('bipartisanreport.com', 374),
#  ('survivalknowhow.net', 370),
#  ('filmsforaction.org', 369),
#  ('dailysurge.com', 358),
#  ('nodisinfo.com', 357),
#  ('stuppid.com', 356),
#  ('blacklistednews.com', 353),
#  ('dailyheadlines.com', 351),
#  ('hangthebankers.com', 350),
#  ('www.theaureport.com', 348),
#  ('stneotscitizen.com', 332),
#  ('thebigriddle.com', 331),
#  ('truthnetwork.com', 322),
#  ('redrocktribune.com', 322),
#  ('whydontyoutrythis.com', 321),
#  ('scrappleface.com', 320),
#  ('islamicanews.com', 316),
#  ('usawatchdog.com', 311),
#  ('theopenscroll.blogspot.com', 310),
#  ('universepolitics.com', 308),
#  ('usadailytime.com', 307),
#  ('healthy-holistic-living.com', 301),
#  ('worldtruth.tv', 299),
#  ('awazetribune.com', 293),
#  ('attn.com', 291),
#  ('responsibletechnology.org', 287),
#  ('huzlers.com', 286),
#  ('www.dutchsinse.com', 280),
#  ('zootfeed.com', 279),
#  ('meanlefthook.com', 275),
#  ('srsroccoreport.com', 274),
#  ('bigamericannews.com', 273),
#  ('americannewsx.com', 271),
#  ('nationalreport.net', 264),
#  ('newsthump.com', 262),
#  ('president45donaldtrump.com', 261),
#  ('trunews.com', 258),
#  ('tribuneherald.net', 258),
#  ('geoengineeringwatch.org', 258),
#  ('nasamoonhoax.com', 257),
#  ('creambmp.com', 255),
#  ('proudemocrat.com', 244),
#  ('christwire.org', 244),
#  ('www.nutritionalanarchy.com', 241),
#  ('dailybuzzlive.com', 238),
#  ('anotherdayintheempire.com', 237),
#  ('rightalert.com', 232),
#  ('www.boilingfrogspost.com', 232),
#  ('counterjihad.com', 220),
#  ('callthecops.net', 217),
#  ('theamericanmirror.com', 212),
#  ('americannews.com', 210),
#  ('clickhole.com', 209),
#  ('govtslaves.info', 202),
#  ('skeptiko.com', 202),
#  ('empireherald.com', 200),
#  ('experimentalvaccines.org', 199),
#  ('conservativefighters.com', 197),
#  ('patriotnewsdaily.com', 197),
#  ('onlineconservativepress.com', 189),
#  ('thenewyorkevening.com', 187),
#  ('theinformedamerican.net', 185),
#  ('smag31.com', 183),
#  ('downtrend.com', 177),
#  ('dailyheadlines.net', 177),
#  ('assassinationscience.com', 174),
#  ('palmerreport.com', 166),
#  ('thevalleyreport.com', 163),
#  ('awm.com', 161),
#  ('jewsnews.co.il', 156),
#  ('beehivebugle.com', 154),
#  ('davidwolfe.com', 149),
#  ('thepoke.co.uk', 148),
#  ('yellowhammernews.com', 145),
#  ('rhotv.com', 144),
#  ('worlddaily.info', 143),
#  ('dailysnark.com', 139),
#  ('abriluno.com', 130),
#  ('federalistpress.com', 128),
#  ('platosguns.com', 128),
#  ('dandygoat.com', 128),
#  ('the-newspapers.com', 126),
#  ('oilgeopolitics.net', 125),
#  ('aheadoftheherd.com', 124),
#  ('sportspickle.com', 122),
#  ('redflagnews.com', 121),
#  ('gaia.com', 118),
#  ('unconfirmedsources.com', 117),
#  ('religionmind.com', 117),
#  ('burrardstreetjournal.com', 116),
#  ('blackgenocide.org', 116),
#  ('unclesamsmisguidedchildren.com', 116),
#  ('reductress.com', 112),
#  ('usa-television.com', 109),
#  ('newcoldwar.org', 107),
#  ('teapartyeconomist.com', 107),
#  ('abcnewsgo.co', 106),
#  ('wundergroundmusic.com', 105),
#  ('dollarvigilante.com', 105),
#  ('illuminati-news.com', 103),
#  ('sgtreport.com', 103),
#  ('100percentfedup.com', 100),
#  ('newstoad.net', 99),
#  ('aceflashman.wordpress.com', 98),
#  ('usadosenews.com', 95),
#  ('itaglive.com', 93),
#  ('johnnyrobish.com', 92),
#  ('TheRundownLive.com', 92),
#  ('ufoholic.com', 89),
#  ('legorafi.fr', 88),
#  ('elkoshary.com', 86),
#  ('intrendtoday.com', 86),
#  ('gopthedailydose.com', 86),
#  ('realtimepolitics.com', 85),
#  ('healthycareandbeauty.com', 85),
#  ('dprogram.net', 83),
#  ('www.shadowstats.com', 83),
#  ('www.ICR.org', 83),
#  ('betootaadvocate.com', 82),
#  ('freewoodpost.com', 82),
#  ('elmundotoday.com', 80),
#  ('openmindmagazine.com', 80),
#  ('angrypatriotmovement.com', 78),
#  ('sheepkillers.com', 77),
#  ('civictribune.com', 76),
#  ('success-street.com', 75),
#  ('objectiveministries.org', 74),
#  ('gatesofvienna.net', 73),
#  ('82.221.129.208', 73),
#  ('www.expose1933.com', 72),
#  ('thewealthwatchman.com', 71),
#  ('readconservatives.news', 70),
#  ('diversitychronicle.wordpress.com', 70),
#  ('cityworldnews.com', 68),
#  ('enhlive.com', 65),
#  ('usaphase.com', 64),
#  ('fprnradio.com', 64),
#  ('uschronicle.com', 63),
#  ('newslogue.com', 62),
#  ('remedydaily.com', 61),
#  ('jamesrgrangerjr.com', 60),
#  ('americanpatriotdaily.com', 59),
#  ('wealthwire.com', 59),
#  ('now8news.com', 57),
#  ('libertyvideos.org', 57),
#  ('fantasticword.com', 57),
#  ('theforbiddenknowledge.com', 57),
#  ('rockcitytimes.com', 56),
#  ('learnprogress.org', 55),
#  ('americanoverlook.com', 54),
#  ('redcountry.us', 54),
#  ('world24monitor.com', 54),
#  ('weshapelife.org', 53),
#  ('viralactions.com', 53),
#  ('uspoliticslive.com', 52),
#  ('loanpride.com', 51),
#  ('www.rightsidenews.com', 50),
#  ('usinfonews.com', 50),
#  ('other98.com', 50),
#  ('citizensunited.org', 49),
#  ('financialsurvivalnetwork.com', 49),
#  ('derfmagazine.com', 49),
#  ('patriotrising.com', 48),
#  ('politicalpiehole.com', 48),
#  ('fognews.ru', 48),
#  ('onepoliticalplaza.com', 45),
#  ('viraltube.nl', 45),
#  ('thewashingtonpress.com', 45),
#  ('northcrane.com', 44),
#  ('mad-yet.blogspot.com', 44),
#  ('therightplanet.com', 44),
#  ('concisepolitics.com', 43),
#  ('www.davejanda.com', 43),
#  ('dineal.com', 43),
#  ('glaringhypocrisy.com', 42),
#  ('anonjekloy.tk', 42),
#  ('notallowedto.com', 42),
#  ('elelephantintheroom.blogspot.com', 42),
#  ('donaldtrumpnews.co', 41),
#  ('patriotarchives.blogspot.com', 40),
#  ('lushforlife.com', 39),
#  ('newswire-24.com', 38),
#  ('lightlybraisedturnip.com', 38),
#  ('usafirstinformation.com', 38),
#  ('libertytalk.fm', 37),
#  ('flashnewscorner.com', 37),
#  ('newsbreakers.org', 36),
#  ('sonsoflibertyradio.com', 35),
#  ('dailycurrant.com', 34),
#  ('yournationnews.com', 34),
#  ('metropolitanworlds.com', 34),
#  ('yesimright.com', 33),
#  ('duhprogressive.com', 33),
#  ('debunkingskeptics.com', 33),
#  ('liberaldarkness.com', 33),
#  ('usapoliticszone.com', 32),
#  ('news4ktla.com', 31),
#  ('dailyleak.org', 31),
#  ('politicsinusa.com', 31),
#  ('sensationalisttimes.com', 30),
#  ('TragedyandHope.com', 30),
#  ('dataasylum.com', 29),
#  ('madpatriots.com', 28),
#  ('drudgereport.com', 28),
#  ('usatwentyfour.com', 27),
#  ('thecivilian.co.nz', 26),
#  ('libertywritersnews.com', 26),
#  ('winningdemocrats.com', 25),
#  ('www.silverbearcafe.com', 24),
#  ('proamericanews.com', 24),
#  ('stormcloudsgathering.com', 23),
#  ('observatorial.com', 22),
#  ('uspoln.com', 22),
#  ('dailyoccupation.com', 22),
#  ('dailypoliticsusa.com', 22),
#  ('therightists.com', 22),
#  ('livefreelivenatural.com', 21),
#  ('worldwidehealthy.com', 21),
#  ('guccifer2.wordpress.com', 20),
#  ('www.redicecreations.com', 19),
#  ('zaytung.com', 19),
#  ('electionnightgatekeepers.com', 19),
#  ('rumormillnews.com', 18),
#  ('firearmscoalition.org', 18),
#  ('worldpoliticsnow.com', 17),
#  ('countdowntozerotime.com', 16),
#  ('newcenturytimes.com', 16),
#  ('turnerradionetwork.com', 15),
#  ('conservativespirit.com', 15),
#  ('adobochronicles.com', 15),
#  ('silverstealers.net', 15),
#  ('NoMoreFakeNews.com', 15),
#  ('everydayworldnews.com', 15),
#  ('rogue-nation3.com', 14),
#  ('krbcnews.com', 14),
#  ('horowitzfreedomcenter.org', 14),
#  ('globalpoliticsnow.com', 14),
#  ('www.nationalufocenter.com', 14),
#  ('cap-news.com', 13),
#  ('channel18news.com', 13),
#  ('365usanews.com', 12),
#  ('redstatewatcher.com', 12),
#  ('goneleft.com', 12),
#  ('proudcons.com', 12),
#  ('24newsflash.com', 12),
#  ('ThePeoplesVoice.net', 12),
#  ('awdnews.com', 12),
#  ('theamericancause.org', 11),
#  ('silentmajoritypatriots.com', 11),
#  ('witscience.org', 10),
#  ('amtvmedia.com', 10),
#  ('blackinusrancenews.com', 10),
#  ('themadisonmisnomer.com', 10),
#  ('speciallifeentertainment.com', 9),
#  ('dailypolitics.info', 9),
#  ('conspiracyplanet.com', 9),
#  ('ruptly.tv', 9),
#  ('reagancoalition.com', 9),
#  ('wtoe5news.com', 8),
#  ('politicsinformation.com', 8),
#  ('ilovemyfreedom.org', 8),
#  ('topnewspolitics.com', 8),
#  ('usaonlinepolitics.com', 8),
#  ('nationindistress.weebly.com', 8),
#  ('usfanzone.com', 8),
#  ('newsopening.com', 8),
#  ('unitedmediapublishing.com', 7),
#  ('speld.nl', 6),
#  ('trueactivist.com', 6),
#  ('thestatelyharold.com', 6),
#  ('therundownlive.com', 5),
#  ('subjectpolitics.com', 5),
#  ('newscorpse.com', 5),
#  ('cryptogon.com', 5),
#  ('sourceplanet.net', 5),
#  ('trendingnewsguide.com', 5),
#  ('WideAwakeAmerica.com', 5),
#  ('geopolmonitor.com', 4),
#  ('theoxymoron.co.uk', 4),
#  ('theseattletribune.com', 4),
#  ('www.acting-man.com', 4),
#  ('16wmpo.com', 4),
#  ('dont-tread-on.me', 4),
#  ('wordpress.com', 4),
#  ('embols.com', 3),
#  ('thetruthseeker.co.uk', 3),
#  ('interestingdailynews.com', 3),
#  ('mrconservative.com', 3),
#  ('newsmagazine.com', 3),
#  ('newsbiscuit.com', 3),
#  ('departedmedia.com', 3),
#  ('aurora-news.us', 3),
#  ('www.Jesus-is-Savior.com', 3),
#  ('usatoday.com.co', 3),
#  ('departed.co', 3),
#  ('theskunk.org', 3),
#  ('react365.com', 3),
#  ('usa-radio.com', 2),
#  ('actforamerica.org/news', 2),
#  ('ITCCS.org', 2),
#  ('thelibertymill.com', 2),
#  ('usanewstoday.com', 2),
#  ('newsbreakshere.com', 2),
#  ('dailynews10.com', 2),
#  ('www.DailyKos.com', 2),
#  ('thepoliticalcesspool.com', 2),
#  ('gangstergovernment.com', 2),
#  ('FarmWars.info', 2),
#  ('ExperimentalVaccines.org', 2),
#  ('theracketreport.com', 2),
#  ('extraclubmagazine.com', 2),
#  ('realplanetnews.com', 2),
#  ('checkoutthehealthyworld.com', 2),
#  ('heresyblog.net', 2),
#  ('bients.com', 2),
#  ('usanewsflash.com', 2),
#  ('www.brotherjohnf.com', 2),
#  ('times.com.mx', 2),
#  ('odgossip.com', 2),
#  ('BadSquad.com', 2),
#  ('amplifyingglass.com', 2),
#  ('www.stevequayle.com', 2),
#  ('adflegal.org/media', 2),
#  ('AutomaticEarth.com', 2),
#  ('FreeBeacon.com', 2),
#  ('ItMakesSenseBlog.com', 2),
#  ('dailytelegraph.com.au', 2),
#  ('libertyalliance.com', 2),
#  ('dailydiscord.com', 2),
#  ('patriotupdate.com', 2),
#  ('pakalertpress.com', 2),
#  ('FinancialSurvivalNetwork.com', 2),
#  ('Alt-Market.com', 2),
#  ('righton.com', 2),
#  ('Dutchsinse.com', 2),
#  ('www.silverstealers.net', 2),
#  ('conservativebyte.com', 2),
#  ('www.TragedyAndHope.com', 2),
#  ('topinfopost.com', 2),
#  ('ConservativeHQ.com', 1),
#  ('WolfStreet.com', 1),
#  ('theautogear.com', 1),
#  ('WallStreetOnParade.com', 1),
#  ('worldrumor.com', 1),
#  ('educateinspirechange.org/health', 1),
#  ('thebeaverton.com', 1),
#  ('statenation.co', 1),
#  ('uslifetoday.com', 1),
#  ('thetimesoftheworld.com', 1),
#  ('PoliticalPieHole.com', 1),
#  ('Amposts.com', 1),
#  ('washingtonfed.com', 1),
#  ('DProgram.net', 1),
#  ('Dont-Tread-On.Me', 1),
#  ('abcnews.com.co', 1),
#  ('TDTalliance.com', 1),
#  ('bigbluevision.com', 1),
#  ('usahitman.com', 1),
#  ('powerpoliticians.com', 1),
#  ('www.UsChronicle.com', 1),
#  ('TomWoods.com', 1),
#  ('24wpn.com', 1),
#  ('www.thedailycrux.com', 1),
#  ('DonaldTrumpPotus45.com', 1),
#  ('www.NewsWithViews.com', 1),
#  ('tellmenow.com', 1),
#  ('www.Thecarsmagazine.com', 1),
#  ('creativitymovement.net/category/news/', 1),
#  ('www.informationclearinghouse.INFO', 1),
#  ('www.TheLastGreatStand.com', 1),
#  ('dailynewspolitic.com', 1),
#  ('thelastlineofdefense.org', 1),
#  ('GlobalEconomicAnalysis.com', 1),
#  ('REALfarmacy.com', 1),
#  ('www.zengardner.com', 1),
#  ('thedailycrux.com', 1),
#  ('mediamass.net', 1),
#  ('bigbluevision.org', 1),
#  ('Zengardner.com', 1),
#  ('davejanda.com', 1),
#  ('farmwars.info', 1),
#  ('NewsBuster.com', 1),
#  ('X22Report.com', 1),
#  ('SRSroccoReport.com', 1),
#  ('newscenterusa.com', 1),
#  ('bostontribune.com', 1),
#  ('Newsmax.com', 1),
#  ('bighairynews.com', 1),
#  ('amusmentic.com', 1),
#  ('disclosuremedia.net', 1),
#  ('theunrealtimes.com', 1),
#  ('ushealthylife.com', 1),
#  ('worldstoriestoday.com', 1),
#  ('alternativemediasyndicate.com', 1),
#  ('surrealscoop.com', 1),
#  ('rightsidenews.com', 1),
#  ('TruthStreamMedia.com', 1),
#  ('Mad-Yet.blogspot.com', 1),
#  ('TheRacketReport.com', 1),
#  ('cannasos.com', 1),
#  ('bostonleader.com', 1),
#  ('smartknowledgeu.com/blog', 1),
#  ('politicalears.com', 1),
#  ('newyorker.com/humor', 1),
#  ('TheBRICSPost.com', 1),
#  ('conservativeflashnews.com', 1),
#  ('nephef.com', 1),
#  ('TheRightPlanet.com', 1),
#  ('en.wordpress.com', 1),
#  ('TheTruthWins.com', 1),
#  ('TurnerRadioNetwork.com', 1),
#  ('thecarsmagazine.com', 1),
#  ('szandorblestman.com/index.php', 1),
#  ('ihavethetruth.com', 1),
#  ('wonkie.com', 1),
#  ('voxtribune.com', 1),
#  ('TheWealthWatchman.com', 1),
#  ('USAWatchdog.com', 1),
#  ('www.sott.NET', 1),
#  ('rilenews.com', 1),
#  ('cbsnews.com.co', 1),
#  ('wakeupthesheep.com', 1),
#  ('thatviralfeed.net', 1),
#  ('Oftwominds.com', 1),
#  ('news-hound.org', 1),
#  ('SilverStealers.net', 1),
#  ('aanirfan.blogspot.ie', 1),
#  ('www.badsquad.com', 1),
#  ('solari.com/blog', 1),
#  ('usviewer.com', 1),
#  ('zengardner.com', 1),
#  ('SurvivalBlog.com', 1),
#  ('lastdeplorables.com', 1),
#  ('livevote.com', 1),
#  ('trumpvision365.com', 1),
#  ('NoTime4Bull.com', 1),
#  ('usanewsinsider.com', 1),
#  ('themoralofthestory.us', 1),
#  ('nymeta.co', 1),
#  ('www.SonsOfLibertyRadio.com', 1),
#  ('instaworldnews.com', 1),
#  ('WilliamBanzai7.blogspot.com', 1),
#  ('TheVictoryReport.org', 1),
#  ('BrotherJohnF.com', 1),
#  ('associatedmediacoverage.com', 1),
#  ('suggesthealthytips.com', 1),
#  ('rumorjournal.com', 1),
#  ('liberalplug.com', 1),
#  ('ReadyNutrition.com', 1),
#  ('SurvivalKnowHow.net', 1),
#  ('anonnews.co', 1),
#  ('departedme.com', 1),
#  ('spinzon.com', 1),
#  ('TrueActivist.com', 1),
#  ('politicsusanews.com', 1),
#  ('NaturalNews.com', 1),
#  ('politicaltimes.org', 1),
#  ('freedomworldnews.com', 1),
#  ('christiantimesnewspaper.com', 1),
#  ('cato.org/blog', 1),
#  ('www.TruthAndAction.org', 1),
#  ('whitepower.com', 1),
#  ('www.stawealth.com', 1),
#  ('local31news.com', 1),
#  ('www.nomorefakenews.com', 1),
#  ('thebrowser.com', 1),
#  ('nyuzer.com', 1),
#  ('megafreshnews.com', 1),
#  ('www.hugedomains.com', 1),
#  ('bignuggetnews.com', 1),
#  ('NationalUFOCenter.com', 1),
#  ('www.TurnerRadioNetwork.com', 1),
#  ('tap-news.com', 1),
#  ('lifeandabout.com', 1),
#  ('eutopia.buzz', 1),
#  ('RightSideNews.com', 1),
#  ('wideawakeamerica.com', 1),
#  ('usapolitics24hrs.com', 1)]

# %%
df_websites = pd.read_excel('data/7_opensources_co/websites_with_results.xlsx')
domains = [u for u in df_websites.url.values]

domain_type = {}
websites_url = df_websites.url.values
websites_type = df_websites.type.values
for i, url in enumerate(websites_url):
    domain_type[url] = websites_type[i]

# %%
count_domains_in_websites = 0
for domain, _ in domains_counter_sorted:
    if domain in websites_url:
        count_domains_in_websites += 1
        
print(count_domains_in_websites, 'out of', len(websites_url))
# Out:
# 745 out of 1001

# %% [markdown]
# # Merge news_cleaned_2018_01_29 with news_cleaned_postgres

# %%
def insert_bulk(pages, db):
    Page._meta.database = db
    db.connect(reuse_if_open=True)
    
    with db.atomic():
        Page.insert_many(pages).execute()

# %%
batch_size = 50
pages_to_insert = []
with tqdm() as progress:
    for page in fetch_pages(0, batch_size, peewee_database_postgres):
        _page = model_to_dict(page)
        del _page['id']
        
        pages_to_insert.append(_page)
        progress.update()
        
        if len(pages_to_insert) > batch_size:
            insert_bulk(pages_to_insert, peewee_database_2018_01_29_and_postgres)
            pages_to_insert = []   
        
insert_bulk(pages_to_insert, peewee_database_2018_01_29_and_postgres)
# Out:
# 6755636it [1:34:54, 1186.28it/s]
